# %%
import matplotlib
import matplotlib.pyplot as plt
from scipy.interpolate import spline
import numpy as np
from numpy import *
import pylab
import scipy
from matplotlib import rc, rcParams, pyplot
from matplotlib.pyplot import figure, axes, plot, xlabel, ylabel, title, grid, savefig, show
from matplotlib.ticker import MaxNLocator
######################################################################
figure(1,figsize=(8,6))
######################################################################
rc('font', family='TimesRoman', weight = 'extra bold', size = 18.0)
rc('text', usetex=True)
rc('axes', linewidth = 2, labelsize = 'large')  
rc('xtick', labelsize= 'medium')
rcParams['xtick.major.size'] = 12.0 
rcParams['xtick.minor.size'] = 8.0
rcParams['xtick.major.pad'] = 12.0 
rcParams['xtick.minor.pad'] = 12.0
rc('ytick', labelsize= 'medium')  
rcParams['ytick.major.size'] = 12.0 
rcParams['ytick.minor.size'] = 8.0
rcParams['ytick.major.pad'] = 12.0 
rcParams['ytick.minor.pad'] = 12.0
rc('lines', linewidth = 1.5, markeredgewidth=2.0)
rc('savefig', dpi=300)
######################################################################
# Fixing space around the plot
pylab.axes([0.145,0.125,0.825,0.825])

#ax.xaxis.set_major_locator(xmajorLocator)
#ax.xaxis.set_minor_locator(xminorLocator)
#ax.yaxis.set_major_locator(ymajorLocator)
#ax.yaxis.set_minor_locator(yminorLocator)

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_sbs = genfromtxt('output/test-tini=0-x_ini_3p19-_bispectrum_equi_lqc_s.dat')
k = data_sbs[:,0]
sbs = data_sbs[:,1]

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_sbs_mod = genfromtxt('output/mod-test-tini=0-x_ini_3p19-_bispectrum_equi_lqc_s.dat')
k_mod = data_sbs_mod[:,0]
sbs_mod = data_sbs_mod[:,1]

# %%
kp=3.84
plt.loglog(k/kp, absolute(sbs), color='red', linestyle='solid',label=r'$|f_{_{\rm NL}}^{^{\rm EL}}(k)|$')
plt.loglog(k_mod/kp, absolute(sbs_mod), color='blue', linestyle='dashed',label=r'$|f_{_{\rm NL}}^{^{\rm EL}}(k)| {\rm modified}$')
pylab.xlabel(r'$k/k_{\star}$')
pylab.ylabel(r'$|f_{_{\rm NL}}(k)|$')
legend=pylab.legend(loc='upper right', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([1.0e-3,20])
#pylab.ylim([1.0e-4,1.0e+5])
pylab.savefig('fnl-lqc-el-modified.pdf', bbox_inches='tight')
pylab.show()

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_sbs = genfromtxt('output/test-tini=0-x_ini_3p19-sl-_bispectrum_equi_lqc_s.dat')
k = data_sbs[:,0]
sbs = data_sbs[:,1]

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_sbs_mod = genfromtxt('output/mod-test-tini=0-x_ini_3p19-sl-_bispectrum_equi_lqc_s.dat')
k_mod = data_sbs_mod[:,0]
sbs_mod = data_sbs_mod[:,1]

# %%
kp=3.84
plt.loglog(k/kp, absolute(sbs), color='red', linestyle='solid',label=r'$|f_{_{\rm NL}}^{^{\rm SL}}(k)|$')
plt.loglog(k_mod/kp, absolute(sbs_mod), color='blue', linestyle='dashed',label=r'$|f_{_{\rm NL}}^{^{\rm SL}}(k)| {\rm modified}$')
pylab.xlabel(r'$k/k_{\star}$')
pylab.ylabel(r'$|f_{_{\rm NL}}(k)|$')
legend=pylab.legend(loc='upper right', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([1.0e-3,20])
#pylab.ylim([1.0e-4,1.0e+5])
pylab.savefig('fnl-lqc-sl-modified.pdf', bbox_inches='tight')
pylab.show()

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_sbs_el = genfromtxt('output/test-x_ini_3p19-el-_bispectrum_equi_lqc_s.dat')
k_el = data_sbs_el[:,0]
sbs_el = data_sbs_el[:,1]
kp=3.84

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_sbs_sl_7 = genfromtxt('output/test-x_ini_3p19-sl-k3_1em7-_bispectrum_equi_lqc_s.dat')
k_sl_7 = data_sbs_sl_7[:,0]
sbs_sl_7 = data_sbs_sl_7[:,1]

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_sbs_sl_8 = genfromtxt('output/test-x_ini_3p19-sl-k3_1em8-_bispectrum_equi_lqc_s.dat')
k_sl_8 = data_sbs_sl_8[:,0]
sbs_sl_8 = data_sbs_sl_8[:,1]

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_sbs_sl_9 = genfromtxt('output/test-x_ini_3p19-sl-k3_1em9-_bispectrum_equi_lqc_s.dat')
k_sl_9 = data_sbs_sl_9[:,0]
sbs_sl_9 = data_sbs_sl_9[:,1]

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_sbs_sl_10 = genfromtxt('output/test-x_ini_3p19-sl-k3_1em10-_bispectrum_equi_lqc_s.dat')
k_sl_10 = data_sbs_sl_10[:,0]
sbs_sl_10 = data_sbs_sl_10[:,1]

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_sbs_sl_6 = genfromtxt('output/test-x_ini_3p19-sl-k3_1em6-_bispectrum_equi_lqc_s.dat')
k_sl_6 = data_sbs_sl_6[:,0]
sbs_sl_6 = data_sbs_sl_6[:,1]

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_sbs_sl_5 = genfromtxt('output/test-x_ini_3p19-sl-k3_1em5-_bispectrum_equi_lqc_s.dat')
k_sl_5 = data_sbs_sl_5[:,0]
sbs_sl_5 = data_sbs_sl_5[:,1]

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_sbs_sl_4 = genfromtxt('output/test-x_ini_3p19-sl-k3_1em4-_bispectrum_equi_lqc_s.dat')
k_sl_4 = data_sbs_sl_4[:,0]
sbs_sl_4 = data_sbs_sl_4[:,1]

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_sbs_sl_3 = genfromtxt('output/test-x_ini_3p19-sl-k3_1em3-_bispectrum_equi_lqc_s.dat')
k_sl_3 = data_sbs_sl_3[:,0]
sbs_sl_3 = data_sbs_sl_3[:,1]

# %%
kp=3.84
plt.loglog(k_el/kp, absolute(sbs_el), color='red', linestyle='--',label=r'$|f_{_{\rm NL}}^{^{\rm EL}}(k)|$')
plt.loglog(k_sl_6/kp, absolute(sbs_sl_6), color='blue', linestyle='--',label=r'$|f_{_{\rm NL}}^{^{\rm SL}}(k)|;\,k_3=10^{-6}k_{\star}$')
plt.loglog(k_sl_5/kp, absolute(sbs_sl_5), color='cyan', linestyle='--',label=r'$|f_{_{\rm NL}}^{^{\rm SL}}(k)|;\,k_3=10^{-5}k_{\star}$')
plt.loglog(k_sl_4/kp, absolute(sbs_sl_4), color='green', linestyle='--',label=r'$|f_{_{\rm NL}}^{^{\rm SL}}(k)|;\,k_3=10^{-4}k_{\star}$')
plt.loglog(k_sl_3/kp, absolute(sbs_sl_3), color='yellow', linestyle='--',label=r'$|f_{_{\rm NL}}^{^{\rm SL}}(k)|;\,k_3=10^{-3}k_{\star}$')
pylab.xlabel(r'$k/k_{\star}$')
pylab.ylabel(r'$|f_{_{\rm NL}}(k)|$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([1.0e-3,20])
#pylab.ylim([1.0e-4,1.0e+5])
pylab.savefig('fnl-lqc-sl-el_vs_sl.pdf', bbox_inches='tight')
pylab.show()

# %%
kp=3.84
plt.loglog(k_el/kp, absolute(sbs_el), color='red', linestyle='--',label=r'$|f_{_{\rm NL}}^{^{\rm EL}}(k)|$')
plt.loglog(k_sl_10/kp, absolute(sbs_sl_10), color='blue', linestyle=':',label=r'$|f_{_{\rm NL}}^{^{\rm SL}}(k)|;\,k_3=10^{-10}k_{\star}$')
plt.loglog(k_sl_9/kp, absolute(sbs_sl_9), color='cyan', linestyle=':',label=r'$|f_{_{\rm NL}}^{^{\rm SL}}(k)|;\,k_3=10^{-9}k_{\star}$')
plt.loglog(k_sl_8/kp, absolute(sbs_sl_8), color='green', linestyle=':',label=r'$|f_{_{\rm NL}}^{^{\rm SL}}(k)|;\,k_3=10^{-8}k_{\star}$')
plt.loglog(k_sl_7/kp, absolute(sbs_sl_7), color='yellow', linestyle=':',label=r'$|f_{_{\rm NL}}^{^{\rm SL}}(k)|;\,k_3=10^{-7}k_{\star}$')
plt.loglog(k_sl_6/kp, absolute(sbs_sl_6), color='yellow', linestyle=':',label=r'$|f_{_{\rm NL}}^{^{\rm SL}}(k)|;\,k_3=10^{-6}k_{\star}$')
pylab.xlabel(r'$k/k_{\star}$')
pylab.ylabel(r'$|f_{_{\rm NL}}(k)|$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([1.0e-3,20])
#pylab.ylim([1.0e-4,1.0e+5])
pylab.savefig('fnl-lqc-sl-el_vs_sl-1.pdf', bbox_inches='tight')
pylab.show()

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_B_sl_7 = genfromtxt('output/test-B-x_ini_3p19-sl-k3_1em7-_bispectrum_equi_lqc_s.dat')
k_sl_7 = data_B_sl_7[:,0]
B_sl_7 = data_B_sl_7[:,1]

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_B_sl_6 = genfromtxt('output/test-B-x_ini_3p19-sl-k3_1em6-_bispectrum_equi_lqc_s.dat')
k_sl_6 = data_B_sl_6[:,0]
B_sl_6 = data_B_sl_6[:,1]

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_B_sl_5 = genfromtxt('output/test-B-x_ini_3p19-sl-k3_1em5-_bispectrum_equi_lqc_s.dat')
k_sl_5 = data_B_sl_5[:,0]
B_sl_5 = data_B_sl_5[:,1]

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_B_sl_4 = genfromtxt('output/test-B-x_ini_3p19-sl-k3_1em4-_bispectrum_equi_lqc_s.dat')
k_sl_4 = data_B_sl_4[:,0]
B_sl_4 = data_B_sl_4[:,1]

# %%
kp=3.84
#plt.loglog(k_el/kp, absolute(sbs_el), color='red', linestyle='--',label=r'$|f_{_{\rm NL}}^{^{\rm EL}}(k)|$')
#plt.loglog(k_sl_6/kp, absolute(sbs_sl_6), color='blue', linestyle='--',label=r'$|f_{_{\rm NL}}^{^{\rm SL}}(k)|;\,k_3=10^{-6}k_{\star}$')
plt.loglog(k_sl_7/kp, absolute(B_sl_7), color='blue', linestyle='--',label=r'$|{\cal B}^{^{\rm SL}}(k)|;\,k_3=1.\,10^{-7}k_{\star}$')
plt.loglog(k_sl_6/kp, absolute(B_sl_6), color='green', linestyle='--',label=r'$|{\cal B}^{^{\rm SL}}(k)|;\,k_3=1.\,10^{-6}k_{\star}$')
plt.loglog(k_sl_5/kp, absolute(B_sl_5), color='orange', linestyle='--',label=r'$|{\cal B}^{^{\rm SL}}(k)|;\,k_3=1.\,10^{-5}k_{\star}$')
plt.loglog(k_sl_4/kp, absolute(B_sl_4), color='red', linestyle='--',label=r'$|{\cal B}^{^{\rm SL}}(k)|;\,k_3=1.\,10^{-4}k_{\star}$')
#plt.loglog(k_sl_31/kp, absolute(sbs_sl_31), color='red', linestyle='--',label=r'$|f_{_{\rm NL}}^{^{\rm SL}}(k)|;\,k_3=8.\,10^{-3}k_{\star}$')
#plt.loglog(k_sl_3/kp, absolute(sbs_sl_3), color='green', linestyle='--',label=r'$|f_{_{\rm NL}}^{^{\rm SL}}(k)|;\,k_3=10^{-3}k_{\star}$')
pylab.xlabel(r'$k/k_{\star}$')
pylab.ylabel(r'$|{\cal B}_{_{\rm NL}}(k)|$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([1.0e-3,20])
#pylab.ylim([1.0e-4,1.0e+5])
pylab.savefig('Bvsk-SL-ir.pdf', bbox_inches='tight')
pylab.show()

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_sbs_sl_31 = genfromtxt('output/test-x_ini_3p19-sl-k3_8em3-_bispectrum_equi_lqc_s.dat')
k_sl_31 = data_sbs_sl_31[:,0]
sbs_sl_31 = data_sbs_sl_31[:,1]

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_sbs_sl_32 = genfromtxt('output/test-x_ini_3p19-sl-k3_4em3-_bispectrum_equi_lqc_s.dat')
k_sl_32 = data_sbs_sl_32[:,0]
sbs_sl_32 = data_sbs_sl_32[:,1]

# %%
kp=3.84
#plt.loglog(k_el/kp, absolute(sbs_el), color='red', linestyle='--',label=r'$|f_{_{\rm NL}}^{^{\rm EL}}(k)|$')
#plt.loglog(k_sl_6/kp, absolute(sbs_sl_6), color='blue', linestyle='--',label=r'$|f_{_{\rm NL}}^{^{\rm SL}}(k)|;\,k_3=10^{-6}k_{\star}$')
plt.loglog(k_sl_32/kp, absolute(sbs_sl_32), color='blue', linestyle='--',label=r'$|f_{_{\rm NL}}^{^{\rm SL}}(k)|;\,k_3=4.\,10^{-3}k_{\star}$')
plt.loglog(k_sl_31/kp, absolute(sbs_sl_31), color='red', linestyle='--',label=r'$|f_{_{\rm NL}}^{^{\rm SL}}(k)|;\,k_3=8.\,10^{-3}k_{\star}$')
plt.loglog(k_sl_3/kp, absolute(sbs_sl_3), color='green', linestyle='--',label=r'$|f_{_{\rm NL}}^{^{\rm SL}}(k)|;\,k_3=10^{-3}k_{\star}$')
pylab.xlabel(r'$k/k_{\star}$')
pylab.ylabel(r'$|f_{_{\rm NL}}(k)|$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([1.0e-3,20])
#pylab.ylim([1.0e-4,1.0e+5])
pylab.savefig('fnl-lqc-sl-el_vs_sl-1.pdf', bbox_inches='tight')
pylab.show()

# %%
kp=3.84
plt.loglog(k_el/kp, absolute(sbs_el), color='red', linestyle='solid',label=r'$|f_{_{\rm NL}}^{^{\rm EL}}(k)|$')
plt.loglog(k_sl/kp, absolute(sbs_sl), color='blue', linestyle='dashed',label=r'$|f_{_{\rm NL}}^{^{\rm SL}}(k)|$')
pylab.xlabel(r'$k/k_{\star}$')
pylab.ylabel(r'$|f_{_{\rm NL}}(k)|$')
legend=pylab.legend(loc='upper right', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([1.0e-3,20])
#pylab.ylim([1.0e-4,1.0e+5])
pylab.savefig('fnl-lqc-sl-el_vs_sl_k3_1em5.pdf', bbox_inches='tight')
pylab.show()
