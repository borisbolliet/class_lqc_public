# %%
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.interpolate import spline
import numpy as np
from numpy import *
import pylab
import scipy
from matplotlib import rc, rcParams, pyplot
from matplotlib.pyplot import figure, axes, plot, xlabel, ylabel, title, grid, savefig, show
from matplotlib.ticker import MaxNLocator
######################################################################
figure(1,figsize=(8,6))
######################################################################
rc('font', family='TimesRoman', weight = 'extra bold', size = 18.0)
rc('text', usetex=True)
rc('axes', linewidth = 1, labelsize = 'large')  
rc('xtick', labelsize= 'medium')
rcParams['xtick.major.size'] = 6. 
rcParams['xtick.minor.size'] = 3
rcParams['xtick.major.pad'] = 12 
rcParams['xtick.minor.pad'] = 8
rc('ytick', labelsize= 'medium')  
rcParams['ytick.major.size'] = 6 
rcParams['ytick.minor.size'] = 3
rcParams['ytick.major.pad'] = 12 
rcParams['ytick.minor.pad'] = 8
rc('lines', linewidth = 1.5, markeredgewidth=2.0)
rc('savefig', dpi=300)
######################################################################
# Fixing space around the plot
pylab.axes([0.145,0.125,0.825,0.825])

#ax.xaxis.set_major_locator(xmajorLocator)
#ax.xaxis.set_minor_locator(xminorLocator)
#ax.yaxis.set_major_locator(ymajorLocator)
#ax.yaxis.set_minor_locator(yminorLocator)

# %%
#Reading data from files and plotting them
#read from textfile to x and y
#\rho_b = 0.41
data_sps = genfromtxt('job30314/output/test-_pk_lqc_s.dat')
kp1 =  1.788155105133e+03
k_1 = data_sps[:,0]
Ps_1 = data_sps[:,1]
data_sps = genfromtxt('job30323/output/test-_pk_lqc_s.dat')
kp1 = 1.788155105133e+03
k_1a = data_sps[:,0]
Ps_1a = data_sps[:,1]

# %%
#Reading data from files and plotting them
#read from textfile to x and y
#\rho_b = 0.31
data_sps = genfromtxt('job30313/output/test-_pk_lqc_s.dat')
kp2 =  6.912747887022e+02
k_2 = data_sps[:,0]
Ps_2 = data_sps[:,1]
data_sps = genfromtxt('job30322/output/test-_pk_lqc_s.dat')
kp2 =  6.912747887022e+02
k_2a = data_sps[:,0]
Ps_2a = data_sps[:,1]

# %%
#Reading data from files and plotting them
#read from textfile to x and y
#\rho_b = 0.21
data_sps = genfromtxt('job30312/output/test-_pk_lqc_s.dat')
kp3 =   1.946173727585e+01 
k_3 = data_sps[:,0]
Ps_3 = data_sps[:,1]
data_sps = genfromtxt('job30321/output/test-_pk_lqc_s.dat')
kp3 =   1.946173727585e+01
k_3a = data_sps[:,0]
Ps_3a = data_sps[:,1]

# %%
#Reading data from files and plotting them
#read from textfile to x and y
#/rho_b = 0.11
data_sps = genfromtxt('job30311/output/test-_pk_lqc_s.dat')
kp4 =   1.946173727585e+01
k_4 = data_sps[:,0]
Ps_4 = data_sps[:,1]
data_sps = genfromtxt('job30320/output/test-_pk_lqc_s.dat')
kp4 =   1.946173727585e+01
k_4a = data_sps[:,0]
Ps_4a = data_sps[:,1]

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(k_1/kp1, Ps_1, color='k', linestyle='None',marker='o',markeredgewidth=0.,markersize = 4,label=r'$\rho_b = 0.41 m_{_{\rm Pl}}^4$')
plot(k_1a/kp1, Ps_1a, color='k', linestyle='None',marker='o',markeredgewidth=0.,markersize = 4)
plot(k_2/kp2, Ps_2, color='slategrey', linestyle='None',marker='v',markeredgewidth=0.,markersize = 4,label=r'$\rho_b = 0.31 m_{_{\rm Pl}}^4$')
plot(k_2a/kp2, Ps_2a, color='slategrey', linestyle='None',marker='v',markeredgewidth=0.,markersize = 4)
#plot(k_3/kp3, Ps_3, color='grey', linestyle='None',marker='+',markeredgewidth=1.,markersize = 4,label=r'$\phi_b = 1.15 m_{_{\rm Pl}}$')
#plot(k_3a/kp3, Ps_3a, color='grey', linestyle='None',marker='+',markeredgewidth=1.,markersize = 4)
plot(k_4/kp4, Ps_4, color='lightgrey', linestyle='None',marker='*',markeredgewidth=0.,markersize = 4,label=r'$\rho_b = 0.11 m_{_{\rm Pl}}^4$')
plot(k_4a/kp4, Ps_4a, color='lightgrey', linestyle='None',marker='*',markeredgewidth=0.,markersize = 4)
pylab.annotate(r'$\phi_b = 1.18 m_{_{\rm Pl}}$', xy=(1.e-1,2.e-8),  xycoords='data',fontsize=12)
#plot(k_p1/kp, Ps_p1, color='grey', linestyle='None',marker='o',markeredgewidth=0.,markersize = 4)
#plot(k_o/kp, Ps_o, color='red', linestyle='-',linewidth=0.25)
#plot([1.607738e+01/kp,1.607738e+01/kp],[1e-12,1e-6],linestyle='--',color='black',linewidth=0.5)
#pylab.annotate(r'$k_{_{\rm LQC}}$', xy=(275,290),  xycoords='figure points',fontsize=12)
plt.xscale('log')
plt.yscale('log')
legend=pylab.legend(loc='best', numpoints=1, shadow=False,frameon=True,prop={'size':13})
pylab.xlabel(r'$k/k_*$')
pylab.ylabel(r'${\cal P}_s(k)$')
pylab.xlim([1.e-7,1.e1])
pylab.ylim([1e-12,1e-7])
pylab.savefig('Ps-rhob.pdf', bbox_inches='tight')
#pylab.show()

# %%
#Reading data from files and plotting them
#read from textfile to x and y
#\rho_b = 0.41
data_sps = genfromtxt('job30314/output/test-_bispectrum_equi_lqc_s.dat')
kp1 =  1.788155105133e+03
k_1 = data_sps[:,0]
fnl_1 = data_sps[:,1]
data_sps = genfromtxt('job30323/output/test-_bispectrum_equi_lqc_s.dat')
kp1 = 1.788155105133e+03
k_1a = data_sps[:,0]
fnl_1a = data_sps[:,1]

# %%
#Reading data from files and plotting them
#read from textfile to x and y
#\rho_b = 0.31
data_sps = genfromtxt('job30313/output/test-_bispectrum_equi_lqc_s.dat')
kp2 =  6.912747887022e+02
k_2 = data_sps[:,0]
fnl_2 = data_sps[:,1]
data_sps = genfromtxt('job30322/output/test-_bispectrum_equi_lqc_s.dat')
kp2 =  6.912747887022e+02
k_2a = data_sps[:,0]
fnl_2a = data_sps[:,1]

# %%
#Reading data from files and plotting them
#read from textfile to x and y
#\rho_b = 0.21
data_sps = genfromtxt('job30312/output/test-_bispectrum_equi_lqc_s.dat')
kp3 =   1.946173727585e+01 
k_3 = data_sps[:,0]
fnl_3 = data_sps[:,1]
data_sps = genfromtxt('job30321/output/test-_bispectrum_equi_lqc_s.dat')
kp3 =   1.946173727585e+01
k_3a = data_sps[:,0]
fnl_3a = data_sps[:,1]

# %%
#Reading data from files and plotting them
#read from textfile to x and y
#/rho_b = 0.11
data_sps = genfromtxt('job30311/output/test-_bispectrum_equi_lqc_s.dat')
kp4 =   1.946173727585e+01
k_4 = data_sps[:,0]
fnl_4 = data_sps[:,1]
data_sps = genfromtxt('job30320/output/test-_bispectrum_equi_lqc_s.dat')
kp4 =   1.946173727585e+01
k_4a = data_sps[:,0]
fnl_4a = data_sps[:,1]

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(k_1/kp1, fnl_1, color='k', linestyle='None',marker='o',markeredgewidth=0.,markersize = 4,label=r'$\rho_b = 0.41 m_{_{\rm Pl}}^4$')
plot(k_1a/kp1, fnl_1a, color='k', linestyle='None',marker='o',markeredgewidth=0.,markersize = 4)
plot(k_2/kp2, fnl_2, color='slategrey', linestyle='None',marker='v',markeredgewidth=0.,markersize = 4,label=r'$\rho_b = 0.31 m_{_{\rm Pl}}^4$')
plot(k_2a/kp2, fnl_2a, color='slategrey', linestyle='None',marker='v',markeredgewidth=0.,markersize = 4)
#plot(k_3/kp3, fnl_3, color='grey', linestyle='None',marker='+',markeredgewidth=1.,markersize = 4,label=r'$\phi_b = 1.15 m_{_{\rm Pl}}$')
#plot(k_3a/kp3, fnl_3a, color='grey', linestyle='None',marker='+',markeredgewidth=1.,markersize = 4)
plot(k_4/kp4, fnl_4, color='lightgrey', linestyle='None',marker='*',markeredgewidth=0.,markersize = 4,label=r'$\rho_b = 0.11 m_{_{\rm Pl}}^4$')
plot(k_4a/kp4, fnl_4a, color='lightgrey', linestyle='None',marker='*',markeredgewidth=0.,markersize = 4)
pylab.annotate(r'$\phi_b = 1.18 m_{_{\rm Pl}}$', xy=(2.e0,1.e5),  xycoords='data',fontsize=12)
pylab.annotate(r'$k_1 = k_2 = k_3 = k$', xy=(2.e0,3.e4),  xycoords='data',fontsize=12)
#plot(k_p1/kp, Ps_p1, color='grey', linestyle='None',marker='o',markeredgewidth=0.,markersize = 4)
#plot(k_o/kp, Ps_o, color='red', linestyle='-',linewidth=0.25)
#plot([1.607738e+01/kp,1.607738e+01/kp],[1e-12,1e-6],linestyle='--',color='black',linewidth=0.5)
#pylab.annotate(r'$k_{_{\rm LQC}}$', xy=(275,290),  xycoords='figure points',fontsize=12)
plt.xscale('log')
plt.yscale('log')
legend=pylab.legend(loc='best', numpoints=1, shadow=False,frameon=True,prop={'size':13})
pylab.xlabel(r'$k/k_*$')
pylab.ylabel(r'$f_{_{\rm NL}}(k)$')
pylab.xlim([1.e-4,1.e2])
pylab.ylim([1e-3,1e6])
pylab.savefig('fnl-el-rhob.pdf', bbox_inches='tight')
#pylab.show()
