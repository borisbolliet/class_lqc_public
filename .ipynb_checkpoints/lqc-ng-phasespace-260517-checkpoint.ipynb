# %%
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.interpolate import spline
import numpy as np
from numpy import *
import pylab
import scipy
from matplotlib import rc, rcParams, pyplot
from matplotlib.pyplot import figure, axes, plot, xlabel, ylabel, title, grid, savefig, show
from matplotlib.ticker import MaxNLocator
######################################################################
figure(1,figsize=(8,6))
######################################################################
rc('font', family='TimesRoman', weight = 'extra bold', size = 18.0)
rc('text', usetex=True)
rc('axes', linewidth = 2, labelsize = 'large')  
rc('xtick', labelsize= 'medium')
rcParams['xtick.major.size'] = 12.0 
rcParams['xtick.minor.size'] = 8.0
rcParams['xtick.major.pad'] = 12.0 
rcParams['xtick.minor.pad'] = 12.0
rc('ytick', labelsize= 'medium')  
rcParams['ytick.major.size'] = 12.0 
rcParams['ytick.minor.size'] = 8.0
rcParams['ytick.major.pad'] = 12.0 
rcParams['ytick.minor.pad'] = 12.0
rc('lines', linewidth = 1.5, markeredgewidth=2.0)
rc('savefig', dpi=300)
######################################################################
# Fixing space around the plot
pylab.axes([0.145,0.125,0.825,0.825])

#ax.xaxis.set_major_locator(xmajorLocator)
#ax.xaxis.set_minor_locator(xminorLocator)
#ax.yaxis.set_major_locator(ymajorLocator)
#ax.yaxis.set_minor_locator(yminorLocator)

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_bg = genfromtxt('output/test-phasespace-mixed_branch-_background_lqc.dat')
t = data_bg[:,0]
a = data_bg[:,1]
x = data_bg[:,2]
y = data_bg[:,3]
H = data_bg[:,4]
epsilon_H = data_bg[:,5]
epsilon_2 = data_bg[:,6]
rho = data_bg[:,7]
phi = data_bg[:,9]
phi_dot = data_bg[:,10]
#f_S = data_bg[:,13]
H2_f_S_Q = data_bg[:,11]
v = data_bg[:,19]
h = data_bg[:,20]
phi = data_bg[:,21]
Pphi = data_bg[:,22]

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_bg_nb = genfromtxt('output/test-phasespace-negative_branch-_background_lqc.dat')
t_nb = data_bg_nb[:,0]
a_nb = data_bg_nb[:,1]
x_nb = data_bg_nb[:,2]
y_nb = data_bg_nb[:,3]
H_nb = data_bg_nb[:,4]
epsilon_H_nb = data_bg_nb[:,5]
epsilon_2_nb = data_bg_nb[:,6]
rho_nb = data_bg_nb[:,7]
phi_nb = data_bg_nb[:,9]
phi_dot_nb = data_bg_nb[:,10]
#f_S = data_bg[:,13]
H2_f_S_Q_nb = data_bg_nb[:,11]
v_nb = data_bg_nb[:,19]
h_nb = data_bg_nb[:,20]
phi_nb = data_bg_nb[:,21]
Pphi_nb = data_bg_nb[:,22]

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_bg_pb = genfromtxt('output/test-phasespace-positive_branch-_background_lqc.dat')
t_pb = data_bg_pb[:,0]
a_pb = data_bg_pb[:,1]
x_pb = data_bg_pb[:,2]
y_pb = data_bg_pb[:,3]
H_pb = data_bg_pb[:,4]
epsilon_H_pb = data_bg_pb[:,5]
epsilon_2_pb = data_bg_pb[:,6]
rho_pb = data_bg_pb[:,7]
phi_pb = data_bg_pb[:,9]
phi_dot_pb = data_bg_pb[:,10]
#f_S = data_bg[:,13]
H2_f_S_Q_pb = data_bg_pb[:,11]
v_pb = data_bg_pb[:,19]
h_pb = data_bg_pb[:,20]
phi_pb = data_bg_pb[:,21]
Pphi_pb = data_bg_pb[:,22]

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_bg_oc = genfromtxt('../class_lqc_ng_config_rho_p41/output/test-rho41-300517-_background_lqc.dat')
t_oc = data_bg_oc[:,0]
a_oc = data_bg_oc[:,1]
x_oc = data_bg_oc[:,2]
y_oc = data_bg_oc[:,3]
H_oc = data_bg_oc[:,4]
epsilon_H_oc = data_bg_oc[:,5]
epsilon_2_oc = data_bg_oc[:,6]
rho_oc = data_bg_oc[:,7]
phi_oc = data_bg_oc[:,11]
phi_dot_oc = data_bg_oc[:,12]
#f_S = data_bg[:,13]
H2_f_S_Q_oc = data_bg_oc[:,15]
#v_pb = data_bg_oc[:,19]
#h_pb = data_bg_oc[:,20]
#phi_pb = data_bg_oc[:,21]
#Pphi_pb = data_bg_oc[:,22]

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, v, color='red', linestyle='-',label=r'bb')
plot(t_nb, v_nb, color='blue', linestyle='--',label=r'nb')
plot(t_pb, v_pb, color='green', linestyle='-.',label=r'pb')
#plot(t_oc, v_oc, color='orange', linestyle='-.',label=r'oc')
#plt.xscale('symlog')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$v$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e0,1.e0])
pylab.ylim([1.e-2,1e1])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (0.01, 10.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, h, color='red', linestyle='-',label=r'bb')
plot(t_nb, h_nb, color='blue', linestyle='--',label=r'nb')
plot(t_pb, h_pb, color='green', linestyle='-.',label=r'pb')
#plt.xscale('symlog')
#plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$h$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e0,1.e0])
#pylab.ylim([0,7])
pylab.savefig('h-compare-branches.pdf', bbox_inches='tight')
#pylab.show()

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, phi, color='red', linestyle='-',label=r'bb')
plot(t_nb, phi_nb, color='blue', linestyle='--',label=r'nb')
plot(t_pb, phi_pb, color='green', linestyle='-.',label=r'pb')
#plt.xscale('symlog')
#plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\phi$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e0,1.e0])
#pylab.ylim([0,7])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-1.0, 1.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, Pphi, color='red', linestyle='-',label=r'bb')
plot(t_nb, Pphi_nb, color='blue', linestyle='--',label=r'nb')
plot(t_pb, Pphi_pb, color='green', linestyle='-.',label=r'pb')
plt.xscale('symlog')
plt.yscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$p_\phi$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e6,1.e6])
pylab.ylim([-1e2,1e2])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-100.0, 100.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, Pphi, color='red', linestyle='-',label=r'bb')
plot(t_nb, Pphi_nb, color='blue', linestyle='--',label=r'nb')
plot(t_pb, Pphi_pb, color='green', linestyle='-.',label=r'pb')
plt.xscale('symlog')
plt.yscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$p_\phi$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e7,1.e7])
#pylab.ylim([1e-2,.2])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-10000000.0, 10000000.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, a, color='red', linestyle='-',label=r'bb')
plot(t_nb, a_nb, color='blue', linestyle='--',label=r'nb')
plot(t_pb, a_pb, color='green', linestyle='-.',label=r'pb')
plot(t_oc, a_oc, color='orange', linestyle=':',label=r'oc')
#plt.xscale('symlog')
#plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$a$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e0,1.e0])
pylab.ylim([0,7])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (0, 7)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, a, color='red', linestyle='-',label=r'bb')
plot(t_nb, a_nb, color='blue', linestyle='--',label=r'nb')
plot(t_pb, a_pb, color='g', linestyle='-.',label=r'pb')
plot(t_oc, a_oc, color='orange', linestyle=':',label=r'oc')
plt.xscale('symlog')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$a$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e7,1.e7])
#pylab.ylim([0,7])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-10000000.0, 10000000.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, H, color='red', linestyle='-',label=r'$bb$')
plot(t_nb, H_nb, color='blue', linestyle='--',label=r'$nb$')
plot(t_pb, H_pb, color='g', linestyle='-.',label=r'$pb$')
plot(t_oc, H_oc, color='orange', linestyle=':',label=r'oc')
#plt.xscale('symlog')
#plt.yscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$H$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e1,1.e1])
#pylab.ylim([-0.5,2])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-10.0, 10.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, H, color='red', linestyle='-',label=r'$bb$')
plot(t_nb, H_nb, color='blue', linestyle='--',label=r'$nb$')
plot(t_pb, H_pb, color='g', linestyle='-.',label=r'$pb$')
plot(t_oc, H_oc, color='orange', linestyle=':',label=r'oc')
plt.xscale('symlog')
plt.yscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$H$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e7,1.e7])
#pylab.ylim([-0.5,2])
pylab.savefig('H-compare-branches.pdf', bbox_inches='tight')
#pylab.show()

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, phi, color='red', linestyle='-',label=r'bb')
plot(t_nb, phi_nb, color='blue', linestyle='--',label=r'nb')
plot(t_pb, phi_pb, color='g', linestyle='-.',label=r'pb')
plot(t_oc, phi_oc, color='orange', linestyle=':',label=r'oc')
#plt.xscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\phi$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e2,1.e2])
#pylab.ylim([-0.5,20])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-100.0, 100.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, phi, color='red', linestyle='-',label=r'bb')
plot(t_nb, phi_nb, color='blue', linestyle='--',label=r'nb')
plot(t_pb, phi_pb, color='g', linestyle='-.',label=r'pb')
plot(t_oc, phi_oc, color='orange', linestyle=':',label=r'oc')
plt.xscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\phi$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e7,1.e7])
#pylab.ylim([-0.5,2])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-10000000.0, 10000000.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, phi_dot, color='red', linestyle='-',label=r'bb')
plot(t_nb, phi_dot_nb, color='blue', linestyle='--',label=r'nb')
plot(t_pb, phi_dot_pb, color='g', linestyle='-.',label=r'pb')
plot(t_oc, phi_dot_oc, color='orange', linestyle=':',label=r'oc')
#plt.xscale('symlog')
#plt.xscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\dot\phi$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e0,1.e0])
#pylab.ylim([-0.5,2])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-1.0, 1.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, phi_dot, color='red', linestyle='-',label=r'bb')
plot(t_nb, phi_dot_nb, color='blue', linestyle='--',label=r'nb')
plot(t_pb, phi_dot_pb, color='g', linestyle='-.',label=r'pb')
plot(t_oc, phi_dot_oc, color='orange', linestyle=':',label=r'oc')
plt.xscale('symlog')
plt.yscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\dot\phi$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e7,1.e7])
pylab.ylim([-1.e2,1e2])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-100.0, 100.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, absolute(H2_f_S_Q), color='red', linestyle='-',label=r'bb')
plot(t_nb, absolute(H2_f_S_Q_nb), color='blue', linestyle='--',label=r'nb')
plot(t_pb, absolute(H2_f_S_Q_pb), color='g', linestyle='-.',label=r'pb')
plot(t_oc, absolute(H2_f_S_Q_oc), color='orange', linestyle=':',label=r'oc')
plt.xscale('symlog')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'${\cal U}$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e7,1.e7])
pylab.ylim([-1.e2,1e2])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (9.6806972487449998e-14, 100.0)

# %%
data_sps = genfromtxt("output/test-phasespace-mixed_branch-_pk_lqc_s.dat")
k = data_sps[:,0]
Ps = data_sps[:,1]
kp = 3.238416e+02

# %%
data_sps_nb = genfromtxt("output/test-phasespace-negative_branch-_pk_lqc_s.dat")
k_nb = data_sps_nb[:,0]
Ps_nb = data_sps_nb[:,1]
kp = 3.238416e+02

# %%
data_sps_pb = genfromtxt("output/test-phasespace-positive_branch-_pk_lqc_s.dat")
k_pb = data_sps_pb[:,0]
Ps_pb = data_sps_pb[:,1]
kp = 3.238416e+02

# %%
data_sps_oc = genfromtxt("../class_lqc_ng_config_rho_p41/output/test-rho41-300517-_pk_lqc_s.dat")
k_oc = data_sps_oc[:,0]
Ps_oc = data_sps_oc[:,1]
kp_oc = 2.833911611787e+02

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(k/kp, Ps, color='red', linestyle='-',label=r'bb')
plot(k_nb/kp, Ps_nb, color='b', linestyle='--',label=r'nb')
plot(k_pb/kp, Ps_pb, color='g', linestyle='-.',label=r'pb')
plot(k_oc/kp_oc, Ps_oc, color='orange', linestyle=':',label=r'oc')
#plot(t_b, absolute(H2_f_S_Q_b), color='blue', linestyle='--',label=r'$old$')
plt.xscale('log')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$k/k_{\star}$')
pylab.ylabel(r'${\cal P}_s(k)$')
#pylab.xlim([-1.e7,1.e7])
#pylab.ylim([1.e-13,1e-7])
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
#pylab.savefig('Ps-compare-branches.pdf', bbox_inches='tight')
#pylab.show()

# %%
data_sbs = genfromtxt("output/test-phasespace-mixed_branch-_bispectrum_equi_lqc_s.dat")
k = data_sbs[:,0]
fnl = data_sbs[:,1]

# %%
data_sbs_nb = genfromtxt("output/test-phasespace-negative_branch-_bispectrum_equi_lqc_s.dat")
k_nb = data_sbs_nb[:,0]
fnl_nb = data_sbs_nb[:,1]

# %%
data_sbs_pb = genfromtxt("output/test-phasespace-positive_branch-_bispectrum_equi_lqc_s.dat")
k_pb = data_sbs_pb[:,0]
fnl_pb = data_sbs_pb[:,1]

# %%
data_sbs_oc = genfromtxt("../class_lqc_ng_config_rho_p41/output/test-rho41-300517-_bispectrum_equi_lqc_s.dat")
k_oc = data_sbs_oc[:,0]
fnl_oc = data_sbs_oc[:,1]

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(k/kp, absolute(fnl), color='red', linestyle='-',label=r'bb')
plot(k_nb/kp, absolute(fnl_nb), color='b', linestyle='-',label=r'nb')
plot(k_pb/kp, absolute(fnl_pb), color='g', linestyle='-',label=r'pb')
plot(k_oc/kp_oc, absolute(fnl_oc), color='orange', linestyle='--',label=r'ic')
#plot(t_b, absolute(H2_f_S_Q_b), color='blue', linestyle='--',label=r'$old$')
plt.xscale('log')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$k/k_{\star}$')
pylab.ylabel(r'$f_{_{\rm NL}}(k)$')
#pylab.xlim([-1.e7,1.e7])
#pylab.ylim([1.e-13,1e-7])
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.savefig('fnl-compare-branches.pdf', bbox_inches='tight')
#pylab.show()
