# %%
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.interpolate import spline
import numpy as np
from numpy import *
import pylab
import scipy
from matplotlib import rc, rcParams, pyplot
from matplotlib.pyplot import figure, axes, plot, xlabel, ylabel, title, grid, savefig, show
from matplotlib.ticker import MaxNLocator
######################################################################
figure(1,figsize=(8,6))
######################################################################
rc('font', family='TimesRoman', weight = 'extra bold', size = 18.0)
rc('text', usetex=True)
rc('axes', linewidth = 2, labelsize = 'large')  
rc('xtick', labelsize= 'medium')
rcParams['xtick.major.size'] = 12.0 
rcParams['xtick.minor.size'] = 8.0
rcParams['xtick.major.pad'] = 12.0 
rcParams['xtick.minor.pad'] = 12.0
rc('ytick', labelsize= 'medium')  
rcParams['ytick.major.size'] = 12.0 
rcParams['ytick.minor.size'] = 8.0
rcParams['ytick.major.pad'] = 12.0 
rcParams['ytick.minor.pad'] = 12.0
rc('lines', linewidth = 1.5, markeredgewidth=2.0)
rc('savefig', dpi=300)
######################################################################
# Fixing space around the plot
pylab.axes([0.145,0.125,0.825,0.825])

#ax.xaxis.set_major_locator(xmajorLocator)
#ax.xaxis.set_minor_locator(xminorLocator)
#ax.yaxis.set_major_locator(ymajorLocator)
#ax.yaxis.set_minor_locator(yminorLocator)

# %%
data_U1 = genfromtxt('output/test-U1-_background_lqc.dat')
t_U1 = data_U1[:,0]
U1 = data_U1[:,11]

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_U2 = genfromtxt('output/test-U2-_background_lqc.dat')
t_U2 = data_U2[:,0]
v_U2 = data_U2[:,19]
h_U2 = data_U2[:,20]
phi_U2 = data_U2[:,21]
#Pphi_U2 = data_U2[:,22]
phi_pert_U2 = data_U2[:,9]
Pphi_pert_U2 = data_U2[:,22]
a_U2 = data_U2[:,1]
H_U2 = data_U2[:,4]
U2 = data_U2[:,11]
zsppbyzs_U2 = data_U2[:,17]
appbya_U2 = data_U2[:,18]
pia_U2 = data_U2[:,23]
piadot_U2 = data_U2[:,29]
Pphidot_U2 = data_U2[:,28]
phidot_U2 = data_U2[:,10]

# %%
data_U3 = genfromtxt('output/test-U3-_background_lqc.dat')
t_U3 = data_U3[:,0]
U3 = data_U3[:,11]

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_nb = genfromtxt('output/background_lqc-nb.txt')
t_nb = data_nb[:,0]
phi_nb = data_nb[:,1]
Pphi_nb = data_U2[:,2]
v_nb = data_nb[:,3]
h_nb = data_nb[:,4]
a_nb = data_nb[:,5]
H_nb = data_nb[:,6]
phi_pert_nb = data_nb[:,7]
Pphi_pert_nb = data_nb[:,8]
pia_nb = data_nb[:,9]
phidot_nb = data_nb[:,10]
piadot_nb = data_nb[:,12]
Pphidot_nb = data_nb[:,11]
U1_nb = data_nb[:,13]
U2_nb = data_nb[:,14]
U3_nb = data_nb[:,15]
zppoz_nb = data_nb[:,16]
appoa_nb = data_nb[:,17]

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t_U1, abs(zsppbyzs_U2), color='red', linestyle='-',label=r'.c')
#plot(t_nb, abs(U1_nb), color='blue', linestyle='--',label=r'.nb')
#plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
plt.xscale('symlog')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$|U_1|$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e5,1.e7])
pylab.ylim([1.e-9,1e4])
pylab.savefig('f.pdf', bbox_inches='tight')
#pylab.show()

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t_U1, abs(-U1), color='red', linestyle='-',label=r'.c')
plot(t_nb, abs(U1_nb), color='blue', linestyle='--',label=r'.nb')
#plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
plt.xscale('symlog')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$|U_1|$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e5,1.e7])
#pylab.ylim([2.48e-9,2.75e-9])
#pylab.savefig('U2-comparison_with_mathematica.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-100000.0, 10000000.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t_U2, abs(-U2), color='red', linestyle='-',label=r'.c')
plot(t_nb, abs(U2_nb), color='blue', linestyle='--',label=r'.nb')
#plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
plt.xscale('symlog')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$|U_2|$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e5,1.e7])
#pylab.ylim([2.48e-9,2.75e-9])
pylab.savefig('U2-comparison_with_mathematica.pdf', bbox_inches='tight')
#pylab.show()

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t_U3, abs(-U3), color='red', linestyle='-',label=r'.c')
plot(t_nb, abs(U3_nb), color='blue', linestyle='--',label=r'.nb')
#plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
plt.xscale('symlog')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$|U_3|$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e5,1.e7])
#pylab.ylim([2.48e-9,2.75e-9])
#pylab.savefig('U2-comparison_with_mathematica.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-100000.0, 10000000.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t_U2, abs(a_U2), color='red', linestyle='-',label=r'.c')
plot(t_nb, abs(a_nb), color='blue', linestyle='--',label=r'.nb')
#plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
plt.xscale('symlog')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$a$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e3,1.e4])
pylab.ylim([0,1e3])
#pylab.savefig('U2-comparison_with_mathematica.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (1.0, 1000.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t_U2, H_U2, color='red', linestyle='-',label=r'.c')
plot(t_nb, H_nb, color='blue', linestyle='--',label=r'.nb')
#plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
plt.xscale('symlog')
plt.yscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$H$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e5,1.e7])
#pylab.ylim([2.48e-9,2.75e-9])
#pylab.savefig('U2-comparison_with_mathematica.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-100000.0, 10000000.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t_U2, phi_U2, color='red', linestyle='-',label=r'.c')
plot(t_nb, phi_nb, color='blue', linestyle='--',label=r'.nb')
#plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
plt.xscale('symlog')
plt.yscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\phi$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e7,1.e7])
#pylab.ylim([2.48e-9,2.75e-9])
#pylab.savefig('U2-comparison_with_mathematica.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-10000000.0, 10000000.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t_U2, Pphi_pert_U2, color='red', linestyle='-',label=r'.c')
plot(t_nb, Pphi_pert_nb, color='blue', linestyle='--',label=r'.nb')
#plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
plt.xscale('symlog')
#plt.yscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$P_{\phi}$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e7,1.e7])
pylab.ylim([-22,30])
#pylab.savefig('U2-comparison_with_mathematica.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-22, 30)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t_U2, Pphidot_U2, color='red', linestyle='-',label=r'.c')
plot(t_nb, Pphidot_nb, color='blue', linestyle='--',label=r'.nb')
#plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
plt.xscale('symlog')
plt.yscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\dot P_{\phi}$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e7,1.e7])
pylab.ylim([-1.e1,1e1])
#pylab.savefig('U2-comparison_with_mathematica.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-10.0, 10.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t_U2, pia_U2, color='red', linestyle='-',label=r'.c')
plot(t_nb, pia_nb, color='blue', linestyle='--',label=r'.nb')
#plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
plt.xscale('symlog')
plt.yscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\pi_a$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e7,1.e7])
pylab.ylim([-1.e30,0])
#pylab.savefig('U2-comparison_with_mathematica.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-1e+30, 0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t_U2, piadot_U2, color='red', linestyle='-',label=r'.c')
plot(t_nb, piadot_nb, color='blue', linestyle='--',label=r'.nb')
#plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
plt.xscale('symlog')
plt.yscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\dot\pi_a$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e7,1.e7])
pylab.ylim([-1.e08,1.e8])
#pylab.savefig('U2-comparison_with_mathematica.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-100000000.0, 100000000.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t_U2, v_U2, color='red', linestyle='-',label=r'.c')
plot(t_nb, v_nb, color='blue', linestyle='--',label=r'.nb')
#plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
plt.xscale('symlog')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$v$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e7,1.e7])
#pylab.ylim([-1.e08,1.e8])
#pylab.savefig('U2-comparison_with_mathematica.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-10000000.0, 10000000.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t_U2, h_U2, color='red', linestyle='-',label=r'.c')
plot(t_nb, h_nb, color='blue', linestyle='--',label=r'.nb')
#plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
plt.xscale('symlog')
#plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$h$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e7,1.e7])
pylab.ylim([-30,1])
#pylab.savefig('U2-comparison_with_mathematica.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-30, 1)
