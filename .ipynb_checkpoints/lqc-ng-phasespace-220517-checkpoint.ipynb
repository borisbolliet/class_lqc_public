# %%
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.interpolate import spline
import numpy as np
from numpy import *
import pylab
import scipy
from matplotlib import rc, rcParams, pyplot
from matplotlib.pyplot import figure, axes, plot, xlabel, ylabel, title, grid, savefig, show
from matplotlib.ticker import MaxNLocator
######################################################################
figure(1,figsize=(8,6))
######################################################################
rc('font', family='TimesRoman', weight = 'extra bold', size = 18.0)
rc('text', usetex=True)
rc('axes', linewidth = 2, labelsize = 'large')  
rc('xtick', labelsize= 'medium')
rcParams['xtick.major.size'] = 12.0 
rcParams['xtick.minor.size'] = 8.0
rcParams['xtick.major.pad'] = 12.0 
rcParams['xtick.minor.pad'] = 12.0
rc('ytick', labelsize= 'medium')  
rcParams['ytick.major.size'] = 12.0 
rcParams['ytick.minor.size'] = 8.0
rcParams['ytick.major.pad'] = 12.0 
rcParams['ytick.minor.pad'] = 12.0
rc('lines', linewidth = 1.5, markeredgewidth=2.0)
rc('savefig', dpi=300)
######################################################################
# Fixing space around the plot
pylab.axes([0.145,0.125,0.825,0.825])

#ax.xaxis.set_major_locator(xmajorLocator)
#ax.xaxis.set_minor_locator(xminorLocator)
#ax.yaxis.set_major_locator(ymajorLocator)
#ax.yaxis.set_minor_locator(yminorLocator)

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_bg = genfromtxt('output/test-phasespace-_background_lqc.dat')
t = data_bg[:,0]
a = data_bg[:,1]
x = data_bg[:,2]
y = data_bg[:,3]
H = data_bg[:,4]
epsilon_H = data_bg[:,5]
epsilon_2 = data_bg[:,6]
rho = data_bg[:,7]
phi = data_bg[:,9]
phi_dot = data_bg[:,10]
#f_S = data_bg[:,13]
H2_f_S_Q = data_bg[:,11]
kp=3.84

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_bg_nb = genfromtxt('output/background_lqc-nb.txt')
t_nb = data_bg_nb[:,0]
phi_nb = data_bg_nb[:,1]
Pphi_nb = data_bg_nb[:,2]
v_nb = data_bg_nb[:,3]
h_nb = data_bg_nb[:,4]
a_nb = data_bg_nb[:,5]
phidot_nb = data_bg_nb[:,6]
H_nb = data_bg_nb[:,7]

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, a, color='red', linestyle='-',label=r'.c')
plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
#plt.xscale('symlog')
#plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$a$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e0,1.e0])
pylab.ylim([0,7])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (0, 7)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, a, color='red', linestyle='-',label=r'.c')
plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
plt.xscale('symlog')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$a$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e7,1.e7])
#pylab.ylim([0,7])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-10000000.0, 10000000.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, H, color='red', linestyle='-',label=r'$old$')
plot(t_nb, H_nb, color='blue', linestyle='--',label=r'$new$')
#plt.xscale('symlog')
#plt.yscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$H$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e0,1.e0])
#pylab.ylim([-0.5,2])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-1.0, 1.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, H, color='red', linestyle='-',label=r'$old$')
plot(t_nb, H_nb, color='blue', linestyle='--',label=r'$new$')
plt.xscale('symlog')
plt.yscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$H$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e7,1.e7])
#pylab.ylim([-0.5,2])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-10000000.0, 10000000.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, phi, color='red', linestyle='-',label=r'.c')
plot(t_nb, phi_nb, color='blue', linestyle='--',label=r'.nb')
#plt.xscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\phi$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e2,1.e2])
#pylab.ylim([-0.5,2])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-100.0, 100.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, phi, color='red', linestyle='-',label=r'.c')
plot(t_nb, phi_nb, color='blue', linestyle='--',label=r'.nb')
plt.xscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\phi$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e7,1.e7])
#pylab.ylim([-0.5,2])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-10000000.0, 10000000.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, phi_dot, color='red', linestyle='-',label=r'.c')
plot(t_nb, phidot_nb, color='blue', linestyle='--',label=r'.nb')
#plt.xscale('symlog')
#plt.xscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\dot\phi$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e0,1.e0])
#pylab.ylim([-0.5,2])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-1.0, 1.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, phi_dot, color='red', linestyle='-',label=r'.c')
plot(t_nb, phidot_nb, color='blue', linestyle='--',label=r'.nb')
plt.xscale('symlog')
plt.xscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\dot\phi$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e7,1.e7])
#pylab.ylim([-0.5,2])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-10000000.0, 10000000.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, x, color='red', linestyle='-',label=r'$new$')
#plot(t_b, x_b, color='blue', linestyle='--',label=r'$old$')
plt.xscale('symlog')
#plt.xscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$x$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e7,2.e7])
#pylab.ylim([-0.5,2])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-10000000.0, 20000000.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, y, color='red', linestyle='-',label=r'$new$')
#plot(t_b, y_b, color='blue', linestyle='--',label=r'$old$')
plt.xscale('symlog')
#plt.xscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$y$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e7,2.e7])
#pylab.ylim([-0.5,2])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-10000000.0, 20000000.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, absolute(H2_f_S_Q), color='red', linestyle='-',label=r'$-{\cal U}$')
#plot(t_b, absolute(H2_f_S_Q_b), color='blue', linestyle='--',label=r'$old$')
plt.xscale('symlog')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$H^2\,f_{S_Q}$')
pylab.xlim([-1.e7,1.e7])
#pylab.ylim([1.e-13,1e-7])
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, absolute(epsilon_H), color='red', linestyle='-',label=r'$\epsilon_H$')
#plot(t_b, absolute(H2_f_S_Q_b), color='blue', linestyle='--',label=r'$old$')
plt.xscale('symlog')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\epsilon_H$')
pylab.xlim([-1.e7,1.e7])
#pylab.ylim([1.e-13,1e-7])
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()

# %%
data_sps = genfromtxt("output/test-phasespace-_pk_lqc_s.dat")
k = data_sps[:,0]
Ps = data_sps[:,1]
kp = 3.238416e2

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(k/kp, Ps, color='red', linestyle='-',label=r'$Ps$')
#plot(t_b, absolute(H2_f_S_Q_b), color='blue', linestyle='--',label=r'$old$')
plt.xscale('log')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$k/k_{\star}$')
pylab.ylabel(r'${\cal P}_s(k)$')
#pylab.xlim([-1.e7,1.e7])
#pylab.ylim([1.e-13,1e-7])
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()

# %%
data_sbs = genfromtxt("output/test-phasespace-_bispectrum_equi_lqc_s.dat")
k = data_sbs[:,0]
fnl = data_sbs[:,1]

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(k/kp, absolute(fnl), color='red', linestyle='-',label=r'$fnl$')
#plot(t_b, absolute(H2_f_S_Q_b), color='blue', linestyle='--',label=r'$old$')
plt.xscale('log')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$k/k_{\star}$')
pylab.ylabel(r'$f_{_{\rm NL}}(k)$')
#pylab.xlim([-1.e7,1.e7])
#pylab.ylim([1.e-13,1e-7])
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
