# %%
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.interpolate import spline
import numpy as np
from numpy import *
import pylab
import scipy
from matplotlib import rc, rcParams, pyplot
from matplotlib.pyplot import figure, axes, plot, xlabel, ylabel, title, grid, savefig, show
from matplotlib.ticker import MaxNLocator
######################################################################
figure(1,figsize=(8,6))
######################################################################
rc('font', family='TimesRoman', weight = 'extra bold', size = 18.0)
rc('text', usetex=True)
rc('axes', linewidth = 1, labelsize = 'large')  
rc('xtick', labelsize= 0.1)#'medium')
rcParams['xtick.major.size'] = 0. 
rcParams['xtick.minor.size'] = 0
rcParams['xtick.major.pad'] = 0 
rcParams['xtick.minor.pad'] = 0
rc('ytick', labelsize= 0.1)#labelsize= 'medium')  
rcParams['ytick.major.size'] = 0 
rcParams['ytick.minor.size'] = 0
rcParams['ytick.major.pad'] = 0 
rcParams['ytick.minor.pad'] = 0
rc('lines', linewidth = 1.5, markeredgewidth=2.0)
rc('savefig', dpi=300)
######################################################################
# Fixing space around the plot
pylab.axes([0.145,0.125,0.825,0.825])

#ax.xaxis.set_major_locator(xmajorLocator)
#ax.xaxis.set_minor_locator(xminorLocator)
#ax.yaxis.set_major_locator(ymajorLocator)
#ax.yaxis.set_minor_locator(yminorLocator)

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_bg = genfromtxt('output/test-phasespace-positive_branch-040617-_background_lqc.dat')
t = data_bg[:,0]
a = data_bg[:,1]
x = data_bg[:,2]
y = data_bg[:,3]
H = data_bg[:,4]
epsilon_H = data_bg[:,5]
epsilon_2 = data_bg[:,6]
rho = data_bg[:,7]
phi = data_bg[:,9]
phi_dot = data_bg[:,10]
#f_S = data_bg[:,13]
H2_f_S_Q = data_bg[:,11]
zS_primeprime_over_zS = data_bg[:,17]
pia_phase = data_bg[:,23]
pia_phys = data_bg[:,24]
H2_f_S_Q_phys = data_bg[:,25]
V= data_bg[:,26]
cosmic_time = data_bg[:,27]

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(phi, V, color='blue', linestyle='-')
plot(1.008779, 2.036274e-11, marker='o', markersize=10, color="red",markeredgewidth=0.)
plot([1.008779,1.008779], [-1.e-9,2.036274e-11], '--', color="red")
plot(5.680, 6.455664e-10, marker='o', markersize=10, color="red",markeredgewidth=0.)
plot([5.680,5.680], [-1.e-9,6.455664e-10], '--', color="red")
plot(1.552180e+01, 4.820901e-09, marker='o', markersize=10, color="red",markeredgewidth=0.)
plot([1.552180e+01,1.552180e+01], [-1.e-9,4.820901e-09], '--', color="red")
#plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
#plt.xscale('symlog')
#plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
#pylab.xlabel(r'$\phi$',labelpad=20)
pylab.ylabel(r'$V(\phi)$')
pylab.annotate(r'$\phi_{\rm end}$', xy=(150, 15),  xycoords='figure points')
pylab.annotate(r'$\phi_{\rm b}$', xy=(202, 15),  xycoords='figure points')
pylab.annotate(r'$\phi_{*}$', xy=(312, 15),  xycoords='figure points')

pylab.annotate(r'$\phi_{\rm end}\, =\, 1.01 M_{_{\rm Pl}}$', xy=(70, 180),  xycoords='figure points',fontsize=10)
pylab.annotate(r'$\phi_{\rm b}\, =\, 5.68 M_{_{\rm Pl}}$', xy=(70, 200),  xycoords='figure points',fontsize=10)
pylab.annotate(r'$\phi_{*}\, =\, 15.52 M_{_{\rm Pl}}$', xy=(70, 220),  xycoords='figure points',fontsize=10)

legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
#pylab.xlim([-1.e0,1.e0])
pylab.ylim([-1e-9,6e-9])
pylab.savefig('potential.eps', bbox_inches='tight')
#pylab.show()

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, zS_primeprime_over_zS, color='blue', linestyle='-')
plt.xscale('symlog')
#plt.yscale('log')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
#pylab.xlim([-1.e0,1.e0])
pylab.ylim([-1e-9,6e-9])
pylab.savefig('potential.eps', bbox_inches='tight')
#pylab.show()

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t,cosmic_time, color='blue', linestyle='-',label=r'.c')
#plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
plt.xscale('symlog')
plt.yscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$\tau$')
pylab.ylabel(r'$t$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
#pylab.xlim([-1.e0,1.e0])
#pylab.ylim([-1e-9,6e-9])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, a, color='red', linestyle='-',label=r'.c')
plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
#plt.xscale('symlog')
#plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$a$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e0,1.e0])
pylab.ylim([0,7])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (0, 7)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, a, color='red', linestyle='-',label=r'.c')
plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
plt.xscale('symlog')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$a$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e7,1.e7])
#pylab.ylim([0,7])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-10000000.0, 10000000.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, H, color='red', linestyle='-',label=r'new')
plot(t_rho41, H_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, H_nb, color='blue', linestyle='--',label=r'$new$')
#plt.xscale('symlog')
#plt.yscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$H$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e0,1.e0])
#pylab.ylim([-0.5,2])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-1.0, 1.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, H, color='red', linestyle='-',label=r'$old$')
plot(t_rho41, H_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, H_nb, color='blue', linestyle='--',label=r'$new$')
plt.xscale('symlog')
plt.yscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$H$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e7,1.e7])
#pylab.ylim([-0.5,2])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-10000000.0, 10000000.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, phi, color='red', linestyle='-',label=r'.c')
plot(t_rho41, phi_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, phi_nb, color='blue', linestyle='--',label=r'.nb')
#plt.xscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\phi$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e2,1.e2])
#pylab.ylim([-0.5,2])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-100.0, 100.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, phi, color='red', linestyle='-',label=r'.c')
plot(t_rho41, phi_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, phi_nb, color='blue', linestyle='--',label=r'.nb')
plt.xscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\phi$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e7,1.e7])
#pylab.ylim([-0.5,2])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-10000000.0, 10000000.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, phi_dot, color='red', linestyle='-',label=r'.c')
plot(t_rho41, phi_dot_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, phidot_nb, color='blue', linestyle='--',label=r'.nb')
#plt.xscale('symlog')
#plt.xscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\dot\phi$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e0,1.e0])
#pylab.ylim([-0.5,2])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-1.0, 1.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, phi_dot, color='red', linestyle='-',label=r'.c')
#plot(t_rho41, phi_dot_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, phidot_nb, color='blue', linestyle='--',label=r'.nb')
plt.xscale('symlog')
plt.xscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\dot\phi$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e7,2.e7])
#pylab.ylim([-0.5,2])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-10000000.0, 20000000.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, x, color='red', linestyle='-',label=r'$new$')
plot(t_rho41, x_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_b, x_b, color='blue', linestyle='--',label=r'$old$')
plt.xscale('symlog')
#plt.xscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$x$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e7,2.e7])
#pylab.ylim([-0.5,2])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-10000000.0, 20000000.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, y, color='red', linestyle='-',label=r'$new$')
plot(t_rho41, y_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_b, y_b, color='blue', linestyle='--',label=r'$old$')
plt.xscale('symlog')
#plt.xscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$y$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e7,2.e7])
#pylab.ylim([-0.5,2])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-10000000.0, 20000000.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, absolute(H2_f_S_Q), color='red', linestyle='-',label=r'$|-{\cal U}|$')
plot(t, absolute(H2_f_S_Q_phys), color='green', linestyle='--',label=r'$|-{\cal U}_{phys}|$')
plot(t_rho41, absolute(H2_f_S_Q_rho41), color='blue', linestyle='--',label=r'\rho_{0.41}')
plot(t, (kp/a)**2, color='black', linestyle='--',label=r'$k_{\star}^2/a^2$')
plt.xscale('symlog')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$H^2\,f_{S_Q}$')
pylab.xlim([-1.e7,1.e7])
pylab.ylim([1.e-13,1e5])
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, absolute(H2_f_S_Q), color='red', linestyle='-',label=r'$|-{\cal U}|$')
plot(t, absolute(H2_f_S_Q_phys), color='green', linestyle='--',label=r'$|-{\cal U}_{phys}|$')
plot(t_rho41, absolute(H2_f_S_Q_rho41), color='blue', linestyle='-.',label=r'\rho_{0.41}')
plt.xscale('symlog')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$H^2\,f_{S_Q}$')
pylab.xlim([-1.e1,1.e1])
pylab.ylim([1.e-13,1e4])
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t,pia_phase , color='red', linestyle='-',label=r'$pia_{phase}$')
plot(t, pia_phys, color='g', linestyle='--',label=r'$pia_{phys}$')
plot(t, pia_phys-3.14/0.11*a*a*6, color='g', linestyle='--',label=r'$pia_{phys}$')
#plot(t_b, absolute(H2_f_S_Q_b), color='blue', linestyle='--',label=r'$old$')
plt.xscale('symlog')
plt.yscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\pi_a$')
pylab.xlim([-1.e1,1.e1])
pylab.ylim([-1.e5,1e5])
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, absolute(epsilon_H), color='red', linestyle='-',label=r'new')
plot(t_rho41, absolute(epsilon_H_rho41), color='b', linestyle='--',label=r'old')
#plot(t_b, absolute(H2_f_S_Q_b), color='blue', linestyle='--',label=r'$old$')
plt.xscale('symlog')
#plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\epsilon_H$')
pylab.xlim([-1.e7,1.e7])
#pylab.ylim([1.e-13,1e-7])
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, epsilon_2, color='red', linestyle='-',label=r'new')
plot(t_rho41, epsilon_2_rho41, color='b', linestyle='--',label=r'old')
#plot(t_b, absolute(H2_f_S_Q_b), color='blue', linestyle='--',label=r'$old$')
plt.xscale('symlog')
#plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\epsilon_2$')
pylab.xlim([-1.e7,1.e7])
pylab.ylim([-0.5,4])
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()

# %%
data_sps = genfromtxt("output/test-phasespace-positive_branch-_pk_lqc_s.dat")
k = data_sps[:,0]
Ps = data_sps[:,1]
kp = 3.238416e2

# %%
data_sps_phys = genfromtxt("output/test-phasespace-positive_branch-phys-_pk_lqc_s.dat")
k_phys = data_sps_phys[:,0]
Ps_phys = data_sps_phys[:,1]

# %%
data_sps_phys = genfromtxt("../class_lqc_ng_config_rho_p41/output/test-rho41-280517-_pk_lqc_s.dat")
k_rho41 = data_sps_phys[:,0]
Ps_rho41 = data_sps_phys[:,1]
kp_rho41 = 3.046961e+02

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(k_rho41/kp_rho41, Ps_rho41, color='b', linestyle='-',label=r'$Ps_{\rho_{.41}}$')
plot(k/kp, Ps, color='red', linestyle='--',label=r'$Ps$')
plot(k_phys/kp, Ps_phys, color='green', linestyle='-',label=r'$Ps_{phys}$')

#plot(t_b, absolute(H2_f_S_Q_b), color='blue', linestyle='--',label=r'$old$')
plt.xscale('log')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$k/k_{\star}$')
pylab.ylabel(r'${\cal P}_s(k)$')
#pylab.xlim([-1.e7,1.e7])
pylab.ylim([1.e-10,1e-6])
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()

# %%
data_sbs = genfromtxt("output/test-phasespace-positive_branch-_bispectrum_equi_lqc_s.dat")
k = data_sbs[:,0]
fnl = data_sbs[:,1]

# %%
data_sbs_phys = genfromtxt("output/test-phasespace-positive_branch-phys-_bispectrum_equi_lqc_s.dat")
k_phys = data_sbs_phys[:,0]
fnl_phys = data_sbs_phys[:,1]

# %%
data_sbs_rho41 = genfromtxt("../class_lqc_ng_config_rho_p41/output/test-rho41-280517-_bispectrum_equi_lqc_s.dat")
k_rho41 = data_sbs_rho41[:,0]
fnl_rho41 = data_sbs_rho41[:,1]

# %%
data_sbs = genfromtxt("../class_lqc_phasespace_v5/output/test-ps-v5-inflation-_bispectrum_equi_lqc_s.dat")
k = data_sbs[:,0]
fnl = data_sbs[:,1]
kp=3.238416e+02

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(k/kp, absolute(fnl), color='red', linestyle='-',label=r'$fnl$')
#plot(k_phys/kp, absolute(fnl_phys), color='g', linestyle='--',label=r'$fnl_{phys}$')
#plot(k_rho41/kp_rho41, absolute(fnl_rho41), color='b', linestyle='--',label=r'$fnl_{\rho_0.41}}$')
#plot(t_b, absolute(H2_f_S_Q_b), color='blue', linestyle='--',label=r'$old$')
plt.xscale('log')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$k/k_{\star}$')
pylab.ylabel(r'$f_{_{\rm NL}}(k)$')
#pylab.xlim([-1.e7,1.e7])
#pylab.ylim([1.e-2,1e-1])
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
#pylab.savefig('fnl-lqc-el-phasespace_v4-phib_5p68.pdf', bbox_inches='tight')
#pylab.show()

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(k/kp, absolute(fnl), color='red', linestyle='-',label=r'$fnl$')
plot(k_phys/kp, absolute(fnl_phys), color='g', linestyle='--',label=r'$fnl_{phys}$')
plot(k_rho41/kp_rho41, absolute(fnl_rho41), color='b', linestyle='--',label=r'$fnl_{\rho_0.41}}$')
#plot(t_b, absolute(H2_f_S_Q_b), color='blue', linestyle='--',label=r'$old$')
plt.xscale('log')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$k/k_{\star}$')
pylab.ylabel(r'$f_{_{\rm NL}}(k)$')
#pylab.xlim([-1.e7,1.e7])
pylab.ylim([1.e-2,1e-1])
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
