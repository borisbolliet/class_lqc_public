# %%
# %pylab inline
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
#import uncertainties as un
pylab.rcParams['figure.figsize'] = (8, 6)
from scipy.interpolate import InterpolatedUnivariateSpline
#from classy import Class
#cosmo=Class()
#cosmo.empty()
#Listparams = dict()
pylab.rcParams['figure.figsize'] = (12, 8)
pylab.rc('text', usetex = False)
pylab.rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#ROOT = 'data/'

# %% [markdown]
# rhoB

# %%
label_size = 22
title_size = 25
legend_size = 18
handle_length = 1.
marker_size = 5.
pylab.rc('text', usetex = True)
pylab.rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})


fig, (ax1) = plt.subplots(1,1,figsize=(7,5))

ax=ax1




K0 = dict()
#K0 = loadtxt('output/test-exact_fR_w=-1._B0=1._synpk.dat')


#K1 = loadtxt('output/test_fRB0=1w=-0.95.pk.dat')
#K0 = loadtxt('output/test_fRB0=1w=-1pk.dat')


#cl_LCDM = K1[:,1]
#ell_LCDM = K1[:,0]
color=iter(cm.rainbow(np.linspace(0,1,8)))


K0 = loadtxt(ROOT+'final-rhob=0.11-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-rhob=0.11-_pk_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\rho_{_{\mathrm{B}}}=0.11\,m_{_{\mathrm{Pl}}}^4$'
colo = 0.45
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)


K0 = loadtxt(ROOT+'final-rhob=0.21-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-rhob=0.21-_pk_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\rho_{_{\mathrm{B}}}=0.21\,m_{_{\mathrm{Pl}}}^4$'
colo -=0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)


K0 = loadtxt(ROOT+'final-rhob=0.31-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-rhob=0.31-_pk_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
y= cl
LABEL =r'$\rho_{_{\mathrm{B}}}=0.31\,m_{_{\mathrm{Pl}}}^4$'
colo -=0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)


K0 = loadtxt(ROOT+'final-rhob=0.41-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-rhob=0.41-_pk_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\rho_{_{\mathrm{B}}}=0.41\,m_{_{\mathrm{Pl}}}^4$'
colo -=0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)




plt.text(0.85,0.9,r'$\phi_{_\mathrm{B}}=1.15\,m_{_{\mathrm{Pl}}}$',horizontalalignment='center',
     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)




ax.set_xlim(3.e-6,7e2)
ax.set_ylim(1.1e-12,1e-6)
ax.set_xscale('log')
ax.set_yscale('log')

ax.set_xlabel(r'$k/k_{\star}$',size=title_size)
ax.set_ylabel(r'$P_{_\mathrm{S}}(k)$',size=title_size)
ax.yaxis.set_label_coords(-.09,0.5) 


ax.legend(loc=4,ncol=2,prop={'size':legend_size},handlelength=handle_length,frameon=True)
ax.tick_params(axis = 'x',which='both',length=5,direction='in', pad=10)
ax.tick_params(axis = 'y',which='both',length=5,direction='in', pad=5)

plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)

ax.xaxis.set_ticks_position('both')

ax.yaxis.set_ticks_position('both')





fig.tight_layout()



#plt.setp(plt.axes().get_yticklabels(), rotation='vertical', fontsize=14)
#plt.setp(plt.axes().get_xticklabels(), fontsize=14)
#plt.xlim(2,2000)
#plt.ylim(1.e0,1.e9)
#plt.xlabel('$k/k_{\star}$',size=20)
#plt.ylabel('$P(k)$',size=20)
#plt.legend(loc=4,prop={'size':16})
#plt.axes().set_xscale('log')
#plt.axes().set_yscale('log')

plt.savefig("pk_rhob.pdf",format='pdf',bbox_inches='tight')

# %%
label_size = 22
title_size = 25
legend_size = 18
handle_length = 1.
marker_size = 5.
pylab.rc('text', usetex = True)
pylab.rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})


fig, (ax1) = plt.subplots(1,1,figsize=(7,5))

ax=ax1




K0 = dict()
#K0 = loadtxt('output/test-exact_fR_w=-1._B0=1._synpk.dat')


#K1 = loadtxt('output/test_fRB0=1w=-0.95.pk.dat')
#K0 = loadtxt('output/test_fRB0=1w=-1pk.dat')


#cl_LCDM = K1[:,1]
#ell_LCDM = K1[:,0]
color=iter(cm.rainbow(np.linspace(0,1,8)))


K0 = loadtxt(ROOT+'final-rhob=0.11-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-rhob=0.11-_pk_lqc_s.dat')
ell = K0[:,0]/np.sqrt(8.*np.pi)
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\rho_{_{\mathrm{B}}}=0.11\,m_{_{\mathrm{Pl}}}^4$'
colo = 0.45
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)


K0 = loadtxt(ROOT+'final-rhob=0.21-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-rhob=0.21-_pk_lqc_s.dat')
ell = K0[:,0]/np.sqrt(8.*np.pi)
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\rho_{_{\mathrm{B}}}=0.21\,m_{_{\mathrm{Pl}}}^4$'
colo -=0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)


K0 = loadtxt(ROOT+'final-rhob=0.31-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-rhob=0.31-_pk_lqc_s.dat')
ell = K0[:,0]/np.sqrt(8.*np.pi)
cl = K0[:,1]
x= ell
y= cl
LABEL =r'$\rho_{_{\mathrm{B}}}=0.31\,m_{_{\mathrm{Pl}}}^4$'
colo -=0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)


K0 = loadtxt(ROOT+'final-rhob=0.41-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-rhob=0.41-_pk_lqc_s.dat')
ell = K0[:,0]/np.sqrt(8.*np.pi)
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\rho_{_{\mathrm{B}}}=0.41\,m_{_{\mathrm{Pl}}}^4$'
colo -=0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)




plt.text(0.85,0.9,r'$\phi_{_\mathrm{B}}=1.15\,m_{_{\mathrm{Pl}}}$',horizontalalignment='center',
     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)




ax.set_xlim(1.e-4,6e2)
ax.set_ylim(1.1e-12,1e-6)
ax.set_xscale('log')
ax.set_yscale('log')

ax.set_xlabel(r'$k\quad[m_{_{\mathrm{Pl}}}]$',size=title_size)
ax.set_ylabel(r'$P_{_\mathrm{S}}(k)$',size=title_size)
ax.yaxis.set_label_coords(-.09,0.5) 

ax.xaxis.set_label_coords(0.5,-0.15) 



ax.legend(loc=4,ncol=2,prop={'size':legend_size},handlelength=handle_length,frameon=True)
ax.tick_params(axis = 'x',which='both',length=5,direction='in', pad=10)
ax.tick_params(axis = 'y',which='both',length=5,direction='in', pad=5)

plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)

ax.xaxis.set_ticks_position('both')

ax.yaxis.set_ticks_position('both')





fig.tight_layout()



#plt.setp(plt.axes().get_yticklabels(), rotation='vertical', fontsize=14)
#plt.setp(plt.axes().get_xticklabels(), fontsize=14)
#plt.xlim(2,2000)
#plt.ylim(1.e0,1.e9)
#plt.xlabel('$k/k_{\star}$',size=20)
#plt.ylabel('$P(k)$',size=20)
#plt.legend(loc=4,prop={'size':16})
#plt.axes().set_xscale('log')
#plt.axes().set_yscale('log')

plt.savefig("pk_rhob_vs_k.pdf",format='pdf',bbox_inches='tight')

# %%
label_size = 22
title_size = 25
legend_size = 18
handle_length = 1.
marker_size = 5.
pylab.rc('text', usetex = True)
pylab.rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})


fig, (ax1) = plt.subplots(1,1,figsize=(7,5))

ax=ax1




K0 = dict()
#K0 = loadtxt('output/test-exact_fR_w=-1._B0=1._synpk.dat')


#K1 = loadtxt('output/test_fRB0=1w=-0.95.pk.dat')
#K0 = loadtxt('output/test_fRB0=1w=-1pk.dat')


#cl_LCDM = K1[:,1]
#ell_LCDM = K1[:,0]
color=iter(cm.rainbow(np.linspace(0,1,8)))


K0 = loadtxt(ROOT+'final-rhob=0.11-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-rhob=0.11-_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\rho_{_{\mathrm{B}}}=0.11\,m_{_{\mathrm{Pl}}}^4$'
colo = 0.45
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)


K0 = loadtxt(ROOT+'final-rhob=0.21-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-rhob=0.21-_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\rho_{_{\mathrm{B}}}=0.21\,m_{_{\mathrm{Pl}}}^4$'
colo -= 0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)




K0 = loadtxt(ROOT+'final-rhob=0.31-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-rhob=0.31-_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\rho_{_{\mathrm{B}}}=0.31\,m_{_{\mathrm{Pl}}}^4$'
colo -= 0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)



K0 = loadtxt(ROOT+'final-rhob=0.41-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-rhob=0.41-_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\rho_{_{\mathrm{B}}}=0.41\,m_{_{\mathrm{Pl}}}^4$'
colo -=0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)





plt.text(0.85,0.9,r'$\phi_{_\mathrm{B}}=1.15\,m_{_{\mathrm{Pl}}}$',horizontalalignment='center',
     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)




ax.set_xlim(3.e-6,7e1)
ax.set_ylim(1.1e-6,5e6)
ax.set_xscale('log')
ax.set_yscale('log')

ax.set_xlabel(r'$k/k_{\star}$',size=title_size)
ax.set_ylabel(r'$|f_{_\mathrm{NL}}(k)|$',size=title_size)
ax.yaxis.set_label_coords(-.09,0.5) 


ax.legend(loc=3,ncol=2,prop={'size':legend_size},handlelength=handle_length,frameon=True)
ax.tick_params(axis = 'x',which='both',length=5,direction='in', pad=10)
ax.tick_params(axis = 'y',which='both',length=5,direction='in', pad=5)

plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)

ax.xaxis.set_ticks_position('both')

ax.yaxis.set_ticks_position('both')





fig.tight_layout()



#plt.setp(plt.axes().get_yticklabels(), rotation='vertical', fontsize=14)
#plt.setp(plt.axes().get_xticklabels(), fontsize=14)
#plt.xlim(2,2000)
#plt.ylim(1.e0,1.e9)
#plt.xlabel('$k/k_{\star}$',size=20)
#plt.ylabel('$P(k)$',size=20)
#plt.legend(loc=4,prop={'size':16})
#plt.axes().set_xscale('log')
#plt.axes().set_yscale('log')

plt.savefig("fNL_rhob.pdf",format='pdf',bbox_inches='tight')

# %%
label_size = 22
title_size = 25
legend_size = 18
handle_length = 1.
marker_size = 5.
pylab.rc('text', usetex = True)
pylab.rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})


fig, (ax1) = plt.subplots(1,1,figsize=(7,5))

ax=ax1




K0 = dict()
#K0 = loadtxt('output/test-exact_fR_w=-1._B0=1._synpk.dat')


#K1 = loadtxt('output/test_fRB0=1w=-0.95.pk.dat')
#K0 = loadtxt('output/test_fRB0=1w=-1pk.dat')


#cl_LCDM = K1[:,1]
#ell_LCDM = K1[:,0]
color=iter(cm.rainbow(np.linspace(0,1,8)))


K0 = loadtxt(ROOT+'final-rhob=0.11-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-rhob=0.11-_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/np.sqrt(8.*np.pi)
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\rho_{_{\mathrm{B}}}=0.11\,m_{_{\mathrm{Pl}}}^4$'
colo = 0.45
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)


K0 = loadtxt(ROOT+'final-rhob=0.21-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-rhob=0.21-_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/np.sqrt(8.*np.pi)
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\rho_{_{\mathrm{B}}}=0.21\,m_{_{\mathrm{Pl}}}^4$'
colo -= 0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)


K0 = loadtxt(ROOT+'final-rhob=0.31-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-rhob=0.31-_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/np.sqrt(8.*np.pi)
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\rho_{_{\mathrm{B}}}=0.31\,m_{_{\mathrm{Pl}}}^4$'
colo -= 0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)



K0 = loadtxt(ROOT+'final-rhob=0.41-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-rhob=0.41-_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/np.sqrt(8.*np.pi)
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\rho_{_{\mathrm{B}}}=0.41\,m_{_{\mathrm{Pl}}}^4$'
colo -=0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)




plt.text(0.85,0.9,r'$\phi_{_\mathrm{B}}=1.15\,m_{_{\mathrm{Pl}}}$',horizontalalignment='center',
     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)




#ax.set_xlim(3.e-6,2e1)
ax.set_xlim(1.e-4,6e2)
ax.set_ylim(1.1e-6,1e6)
ax.set_xscale('log')
ax.set_yscale('log')

ax.set_xlabel(r'$k\quad[m_{_{\mathrm{Pl}}}]$',size=title_size)
ax.set_ylabel(r'$|f_{_\mathrm{NL}}(k)|$',size=title_size)
ax.yaxis.set_label_coords(-.09,0.5) 
ax.xaxis.set_label_coords(0.5,-0.15) 



ax.legend(loc=3,ncol=2,prop={'size':legend_size},handlelength=handle_length,frameon=True)
ax.tick_params(axis = 'x',which='both',length=5,direction='in', pad=10)
ax.tick_params(axis = 'y',which='both',length=5,direction='in', pad=5)

plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)

ax.xaxis.set_ticks_position('both')

ax.yaxis.set_ticks_position('both')





fig.tight_layout()



#plt.setp(plt.axes().get_yticklabels(), rotation='vertical', fontsize=14)
#plt.setp(plt.axes().get_xticklabels(), fontsize=14)
#plt.xlim(2,2000)
#plt.ylim(1.e0,1.e9)
#plt.xlabel('$k/k_{\star}$',size=20)
#plt.ylabel('$P(k)$',size=20)
#plt.legend(loc=4,prop={'size':16})
#plt.axes().set_xscale('log')
#plt.axes().set_yscale('log')

plt.savefig("fNL_rhob_vs_k.pdf",format='pdf',bbox_inches='tight')

# %% [markdown]
# phiB

# %%
label_size = 22
title_size = 25
legend_size = 18
handle_length = 1.
marker_size = 5.
pylab.rc('text', usetex = True)
pylab.rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})


fig, (ax1) = plt.subplots(1,1,figsize=(7,5))

ax=ax1




K0 = dict()
#K0 = loadtxt('output/test-exact_fR_w=-1._B0=1._synpk.dat')


#K1 = loadtxt('output/test_fRB0=1w=-0.95.pk.dat')
#K0 = loadtxt('output/test_fRB0=1w=-1pk.dat')


#cl_LCDM = K1[:,1]
#ell_LCDM = K1[:,0]
color=iter(cm.rainbow(np.linspace(0,1,8)))

K0 = loadtxt(ROOT+'final-phib=5.96-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-phib=5.96-_pk_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\phi_{_\mathrm{B}}=1.19\,m_{_{\mathrm{Pl}}}$'
colo = 0.45
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)


K0 = loadtxt(ROOT+'final-phib=5.86-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-phib=5.86-_pk_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\phi_{_\mathrm{B}}=1.17\,m_{_{\mathrm{Pl}}}$'
colo -=0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)



K0 = loadtxt(ROOT+'final-rhob=0.41-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-rhob=0.41-_pk_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
y= cl
LABEL =r'$\phi_{_\mathrm{B}}=1.15\,m_{_{\mathrm{Pl}}}$'
colo -=0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)



K0 = loadtxt(ROOT+'final-phib=5.66-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-phib=5.66-_pk_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\phi_{_\mathrm{B}}=1.13\,m_{_{\mathrm{Pl}}}$'
colo -=0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)




plt.text(0.85,0.9,r'$\rho_{_{\mathrm{B}}}=0.41\,m_{_{\mathrm{Pl}}}^4$',horizontalalignment='center',
     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)




ax.set_xlim(3.e-6,4e0)
ax.set_ylim(1.1e-12,1e-6)
ax.set_xscale('log')
ax.set_yscale('log')

ax.set_xlabel(r'$k/k_{\star}$',size=title_size)
ax.set_ylabel(r'$P_{_\mathrm{S}}(k)$',size=title_size)
ax.yaxis.set_label_coords(-.09,0.5) 


ax.legend(loc=4,ncol=2,prop={'size':legend_size},handlelength=handle_length,frameon=True)
ax.tick_params(axis = 'x',which='both',length=5,direction='in', pad=10)
ax.tick_params(axis = 'y',which='both',length=5,direction='in', pad=5)

plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)

ax.xaxis.set_ticks_position('both')

ax.yaxis.set_ticks_position('both')





fig.tight_layout()



#plt.setp(plt.axes().get_yticklabels(), rotation='vertical', fontsize=14)
#plt.setp(plt.axes().get_xticklabels(), fontsize=14)
#plt.xlim(2,2000)
#plt.ylim(1.e0,1.e9)
#plt.xlabel('$k/k_{\star}$',size=20)
#plt.ylabel('$P(k)$',size=20)
#plt.legend(loc=4,prop={'size':16})
#plt.axes().set_xscale('log')
#plt.axes().set_yscale('log')

plt.savefig("pk_phib.pdf",format='pdf',bbox_inches='tight')

# %%
label_size = 22
title_size = 25
legend_size = 18
handle_length = 1.
marker_size = 5.
pylab.rc('text', usetex = True)
pylab.rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})


fig, (ax1) = plt.subplots(1,1,figsize=(7,5))

ax=ax1




K0 = dict()
#K0 = loadtxt('output/test-exact_fR_w=-1._B0=1._synpk.dat')


#K1 = loadtxt('output/test_fRB0=1w=-0.95.pk.dat')
#K0 = loadtxt('output/test_fRB0=1w=-1pk.dat')


#cl_LCDM = K1[:,1]
#ell_LCDM = K1[:,0]
color=iter(cm.rainbow(np.linspace(0,1,8)))

K0 = loadtxt(ROOT+'final-phib=5.96-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-phib=5.96-_pk_lqc_s.dat')
ell = K0[:,0]/np.sqrt(8.*np.pi)
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\phi_{_\mathrm{B}}=1.19\,m_{_{\mathrm{Pl}}}$'
colo = 0.45
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)


K0 = loadtxt(ROOT+'final-phib=5.86-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-phib=5.86-_pk_lqc_s.dat')
ell = K0[:,0]/np.sqrt(8.*np.pi)
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\phi_{_\mathrm{B}}=1.17\,m_{_{\mathrm{Pl}}}$'
colo -=0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)



K0 = loadtxt(ROOT+'final-rhob=0.41-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-rhob=0.41-_pk_lqc_s.dat')
ell = K0[:,0]/np.sqrt(8.*np.pi)
cl = K0[:,1]
x= ell
y= cl
LABEL =r'$\phi_{_\mathrm{B}}=1.15\,m_{_{\mathrm{Pl}}}$'
colo -=0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)



K0 = loadtxt(ROOT+'final-phib=5.66-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-phib=5.66-_pk_lqc_s.dat')
ell = K0[:,0]/np.sqrt(8.*np.pi)
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\phi_{_\mathrm{B}}=1.13\,m_{_{\mathrm{Pl}}}$'
colo -=0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)




plt.text(0.85,0.9,r'$\rho_{_{\mathrm{B}}}=0.41\,m_{_{\mathrm{Pl}}}^4$',horizontalalignment='center',
     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)




ax.set_xlim(8.e-5,3e2)
ax.set_ylim(1.1e-12,1e-6)
ax.set_xscale('log')
ax.set_yscale('log')

ax.set_xlabel(r'$k\quad[m_{_{\mathrm{Pl}}}]$',size=title_size)
ax.set_ylabel(r'$P_{_\mathrm{S}}(k)$',size=title_size)
ax.yaxis.set_label_coords(-.09,0.5) 

ax.xaxis.set_label_coords(0.5,-0.15) 




ax.legend(loc=4,ncol=2,prop={'size':legend_size},handlelength=handle_length,frameon=True)
ax.tick_params(axis = 'x',which='both',length=5,direction='in', pad=10)
ax.tick_params(axis = 'y',which='both',length=5,direction='in', pad=5)

plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)

ax.xaxis.set_ticks_position('both')

ax.yaxis.set_ticks_position('both')





fig.tight_layout()



#plt.setp(plt.axes().get_yticklabels(), rotation='vertical', fontsize=14)
#plt.setp(plt.axes().get_xticklabels(), fontsize=14)
#plt.xlim(2,2000)
#plt.ylim(1.e0,1.e9)
#plt.xlabel('$k/k_{\star}$',size=20)
#plt.ylabel('$P(k)$',size=20)
#plt.legend(loc=4,prop={'size':16})
#plt.axes().set_xscale('log')
#plt.axes().set_yscale('log')

plt.savefig("pk_phib_vs_k.pdf",format='pdf',bbox_inches='tight')

# %%
label_size = 22
title_size = 25
legend_size = 18
handle_length = 1.
marker_size = 5.
pylab.rc('text', usetex = True)
pylab.rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})


fig, (ax1) = plt.subplots(1,1,figsize=(7,5))

ax=ax1




K0 = dict()
#K0 = loadtxt('output/test-exact_fR_w=-1._B0=1._synpk.dat')


#K1 = loadtxt('output/test_fRB0=1w=-0.95.pk.dat')
#K0 = loadtxt('output/test_fRB0=1w=-1pk.dat')


#cl_LCDM = K1[:,1]
#ell_LCDM = K1[:,0]
color=iter(cm.rainbow(np.linspace(0,1,8)))

K0 = loadtxt(ROOT+'final-phib=5.96-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-phib=5.96-_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\phi_{_\mathrm{B}}=1.19\,m_{_{\mathrm{Pl}}}$'
colo = 0.45
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)


K0 = loadtxt(ROOT+'final-phib=5.86-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-phib=5.86-_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\phi_{_\mathrm{B}}=1.17\,m_{_{\mathrm{Pl}}}$'
colo -=0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)



K0 = loadtxt(ROOT+'final-rhob=0.41-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-rhob=0.41-_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
y= cl
LABEL =r'$\phi_{_\mathrm{B}}=1.15\,m_{_{\mathrm{Pl}}}$'
colo -=0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)



K0 = loadtxt(ROOT+'final-phib=5.66-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-phib=5.66-_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\phi_{_\mathrm{B}}=1.13\,m_{_{\mathrm{Pl}}}$'
colo -=0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)




plt.text(0.85,0.9,r'$\rho_{_{\mathrm{B}}}=0.41\,m_{_{\mathrm{Pl}}}^4$',horizontalalignment='center',
     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)




ax.set_xlim(3.e-6,4e0)
ax.set_ylim(3e-6,3e6)
ax.set_xscale('log')
ax.set_yscale('log')

ax.set_xlabel(r'$k/k_{\star}$',size=title_size)
ax.set_ylabel(r'$|f_{_\mathrm{NL}}(k)|$',size=title_size)
ax.yaxis.set_label_coords(-.09,0.5) 


ax.legend(loc=3,ncol=2,prop={'size':legend_size},handlelength=handle_length,frameon=True)
ax.tick_params(axis = 'x',which='both',length=5,direction='in', pad=10)
ax.tick_params(axis = 'y',which='both',length=5,direction='in', pad=5)

plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)

ax.xaxis.set_ticks_position('both')

ax.yaxis.set_ticks_position('both')





fig.tight_layout()



#plt.setp(plt.axes().get_yticklabels(), rotation='vertical', fontsize=14)
#plt.setp(plt.axes().get_xticklabels(), fontsize=14)
#plt.xlim(2,2000)
#plt.ylim(1.e0,1.e9)
#plt.xlabel('$k/k_{\star}$',size=20)
#plt.ylabel('$P(k)$',size=20)
#plt.legend(loc=4,prop={'size':16})
#plt.axes().set_xscale('log')
#plt.axes().set_yscale('log')

plt.savefig("fNL_phib.pdf",format='pdf',bbox_inches='tight')

# %%
label_size = 22
title_size = 25
legend_size = 18
handle_length = 1.
marker_size = 5.
pylab.rc('text', usetex = True)
pylab.rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})


fig, (ax1) = plt.subplots(1,1,figsize=(7,5))

ax=ax1




K0 = dict()
#K0 = loadtxt('output/test-exact_fR_w=-1._B0=1._synpk.dat')


#K1 = loadtxt('output/test_fRB0=1w=-0.95.pk.dat')
#K0 = loadtxt('output/test_fRB0=1w=-1pk.dat')


#cl_LCDM = K1[:,1]
#ell_LCDM = K1[:,0]
color=iter(cm.rainbow(np.linspace(0,1,8)))

K0 = loadtxt(ROOT+'final-phib=5.96-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-phib=5.96-_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/np.sqrt(8.*np.pi)
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\phi_{_\mathrm{B}}=1.19\,m_{_{\mathrm{Pl}}}$'
colo = 0.45
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)


K0 = loadtxt(ROOT+'final-phib=5.86-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-phib=5.86-_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/np.sqrt(8.*np.pi)
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\phi_{_\mathrm{B}}=1.17\,m_{_{\mathrm{Pl}}}$'
colo -=0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)



K0 = loadtxt(ROOT+'final-rhob=0.41-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-rhob=0.41-_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/np.sqrt(8.*np.pi)
cl = K0[:,1]
x= ell
y= cl
LABEL =r'$\phi_{_\mathrm{B}}=1.15\,m_{_{\mathrm{Pl}}}$'
colo -=0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)



K0 = loadtxt(ROOT+'final-phib=5.66-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-phib=5.66-_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/np.sqrt(8.*np.pi)
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\phi_{_\mathrm{B}}=1.13\,m_{_{\mathrm{Pl}}}$'
colo -=0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)




plt.text(0.85,0.9,r'$\rho_{_{\mathrm{B}}}=0.41\,m_{_{\mathrm{Pl}}}^4$',horizontalalignment='center',
     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)





ax.set_xlim(8.e-4,3e2)
ax.set_ylim(3e-6,3e6)
ax.set_xscale('log')
ax.set_yscale('log')

ax.set_ylabel(r'$|f_{_\mathrm{NL}}(k)|$',size=title_size)
ax.yaxis.set_label_coords(-.09,0.5) 

ax.set_xlabel(r'$k\quad[m_{_{\mathrm{Pl}}}]$',size=title_size)

ax.xaxis.set_label_coords(0.5,-0.15) 



ax.legend(loc=3,ncol=2,prop={'size':legend_size},handlelength=handle_length,frameon=True)
ax.tick_params(axis = 'x',which='both',length=5,direction='in', pad=10)
ax.tick_params(axis = 'y',which='both',length=5,direction='in', pad=5)

plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)

ax.xaxis.set_ticks_position('both')

ax.yaxis.set_ticks_position('both')





fig.tight_layout()



#plt.setp(plt.axes().get_yticklabels(), rotation='vertical', fontsize=14)
#plt.setp(plt.axes().get_xticklabels(), fontsize=14)
#plt.xlim(2,2000)
#plt.ylim(1.e0,1.e9)
#plt.xlabel('$k/k_{\star}$',size=20)
#plt.ylabel('$P(k)$',size=20)
#plt.legend(loc=4,prop={'size':16})
#plt.axes().set_xscale('log')
#plt.axes().set_yscale('log')

plt.savefig("fNL_phib_vs_k.pdf",format='pdf',bbox_inches='tight')

# %% [markdown]
# cut-off

# %%
label_size = 22
title_size = 25
legend_size = 18
handle_length = 1.
marker_size = 5.
pylab.rc('text', usetex = True)
pylab.rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})


fig, (ax1) = plt.subplots(1,1,figsize=(7,5))

ax=ax1




K0 = dict()
#K0 = loadtxt('output/test-exact_fR_w=-1._B0=1._synpk.dat')


#K1 = loadtxt('output/test_fRB0=1w=-0.95.pk.dat')
#K0 = loadtxt('output/test_fRB0=1w=-1pk.dat')


#cl_LCDM = K1[:,1]
#ell_LCDM = K1[:,0]
color=iter(cm.rainbow(np.linspace(0,1,8)))


K0 = loadtxt(ROOT+'final-delta=0.1-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-delta=0.1-_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\delta=10$'
colo = 0.75
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)


K0 = loadtxt(ROOT+'final-delta=0.5-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-delta=0.5-_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\delta=2$'
colo -=0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)



K0 = loadtxt(ROOT+'final-delta=1-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-delta=1-_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
y= cl
LABEL =r'$\delta=1$'
colo -=0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)



K0 = loadtxt(ROOT+'final-rhob=0.41-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-rhob=0.41-_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\delta=0.1$'
colo -=0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)



K0 = loadtxt(ROOT+'final-delta=20-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-delta=20-_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
y= cl
LABEL =r'$\delta=0.05$'
colo -=0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)



plt.text(0.55,0.9,r'$\rho_{_{\mathrm{B}}}=0.41\,m_{_{\mathrm{Pl}}}^4$\quad\quad\quad$\phi_{_\mathrm{B}}=1.15\,m_{_{\mathrm{Pl}}}$',horizontalalignment='center',
     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)




ax.set_xlim(3.e-6,4e0)
ax.set_ylim(1.5e-6,8.e6)
ax.set_xscale('log')
ax.set_yscale('log')

ax.set_xlabel(r'$k/k_{\star}$',size=title_size)
ax.set_ylabel(r'$|f_{_\mathrm{NL}}(k)|$',size=title_size)
ax.yaxis.set_label_coords(-.09,0.5) 


ax.legend(loc=3,ncol=3,prop={'size':legend_size},handlelength=handle_length,frameon=True)
ax.tick_params(axis = 'x',which='both',length=5,direction='in', pad=10)
ax.tick_params(axis = 'y',which='both',length=5,direction='in', pad=5)

plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)

ax.xaxis.set_ticks_position('both')

ax.yaxis.set_ticks_position('both')





fig.tight_layout()



#plt.setp(plt.axes().get_yticklabels(), rotation='vertical', fontsize=14)
#plt.setp(plt.axes().get_xticklabels(), fontsize=14)
#plt.xlim(2,2000)
#plt.ylim(1.e0,1.e9)
#plt.xlabel('$k/k_{\star}$',size=20)
#plt.ylabel('$P(k)$',size=20)
#plt.legend(loc=4,prop={'size':16})
#plt.axes().set_xscale('log')
#plt.axes().set_yscale('log')

plt.savefig("fNL_delta.pdf",format='pdf',bbox_inches='tight')

# %%
label_size = 22
title_size = 25
legend_size = 18
handle_length = 1.
marker_size = 5.
pylab.rc('text', usetex = True)
pylab.rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})


fig, (ax1) = plt.subplots(1,1,figsize=(7,5))

ax=ax1




K0 = dict()
#K0 = loadtxt('output/test-exact_fR_w=-1._B0=1._synpk.dat')


#K1 = loadtxt('output/test_fRB0=1w=-0.95.pk.dat')
#K0 = loadtxt('output/test_fRB0=1w=-1pk.dat')


#cl_LCDM = K1[:,1]
#ell_LCDM = K1[:,0]
color=iter(cm.rainbow(np.linspace(0,1,8)))


K0 = loadtxt(ROOT+'final-delta=0.1-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-delta=0.1-_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\delta=10$'
colo = 0.75
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)


K0 = loadtxt(ROOT+'final-delta=0.5-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-delta=0.5-_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\delta=2$'
colo -=0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)



K0 = loadtxt(ROOT+'final-delta=1-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-delta=1-_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
y= cl
LABEL =r'$\delta=1$'
colo -=0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)



K0 = loadtxt(ROOT+'final-rhob=0.41-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-rhob=0.41-_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\delta=0.1$'
colo -=0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)



K0 = loadtxt(ROOT+'final-delta=20-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-delta=20-_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
y= cl
LABEL =r'$\delta=0.05$'
colo -=0.15
col = (colo, colo, colo)
ax.plot(x,abs(y),label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)



plt.text(0.85,0.9,r'$\rho_{_{\mathrm{B}}}=0.41\,m_{_{\mathrm{Pl}}}^4$',horizontalalignment='center',
     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)

plt.text(0.85,0.8,r'$\phi_{_\mathrm{B}}=1.15\,m_{_{\mathrm{Pl}}}$',horizontalalignment='center',
     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)





ax.set_xlim(3.e-2,2.3e0)
ax.set_ylim(1.5e-5,8.e1)
ax.set_xscale('log')
ax.set_yscale('log')

ax.set_xlabel(r'$k/k_{\star}$',size=title_size)
ax.set_ylabel(r'$|f_{_\mathrm{NL}}(k)|$',size=title_size)
ax.yaxis.set_label_coords(-.09,0.5) 


ax.legend(loc=3,ncol=3,prop={'size':legend_size},handlelength=handle_length,frameon=True)
ax.tick_params(axis = 'x',which='both',length=5,direction='in', pad=10)
ax.tick_params(axis = 'y',which='both',length=5,direction='in', pad=5)

plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)

ax.xaxis.set_ticks_position('both')

ax.yaxis.set_ticks_position('both')





fig.tight_layout()



#plt.setp(plt.axes().get_yticklabels(), rotation='vertical', fontsize=14)
#plt.setp(plt.axes().get_xticklabels(), fontsize=14)
#plt.xlim(2,2000)
#plt.ylim(1.e0,1.e9)
#plt.xlabel('$k/k_{\star}$',size=20)
#plt.ylabel('$P(k)$',size=20)
#plt.legend(loc=4,prop={'size':16})
#plt.axes().set_xscale('log')
#plt.axes().set_yscale('log')

plt.savefig("fNL_delta_zoom.pdf",format='pdf',bbox_inches='tight')

# %% [markdown]
# tau_end rhoB=0.41
# TBD: check analytical approximation

# %%
label_size = 22
title_size = 25
legend_size = 18
handle_length = 1.
marker_size = 5.
pylab.rc('text', usetex = True)
pylab.rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})


fig, (ax1) = plt.subplots(1,1,figsize=(7,5))

ax=ax1




K0 = dict()
#K0 = loadtxt('output/test-exact_fR_w=-1._B0=1._synpk.dat')


#K1 = loadtxt('output/test_fRB0=1w=-0.95.pk.dat')
#K0 = loadtxt('output/test_fRB0=1w=-1pk.dat')


#cl_LCDM = K1[:,1]
#ell_LCDM = K1[:,0]
color=iter(cm.rainbow(np.linspace(0,1,8)))


K0 = loadtxt(ROOT+'final-tau_end=tau_start_inflation-k3=k_over_100_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-tau_end=tau_start_inflation-k3=k_over_100_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\delta=10$'
colo = 0.
col = (colo, colo, colo)
ax.plot(x,y,label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)



K0 = loadtxt(ROOT+'final-tau_end=tau_start_inflation-k3=k_over_100-k2=k_over_100_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-tau_end=tau_start_inflation-k3=k_over_100-k2=k_over_100_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\delta=2$'
colo =0.15
col = (colo, colo, colo)
ax.plot(x,y,label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)




K0 = loadtxt(ROOT+'final-tau_end=tau_start_inflation-k3=k_over_2-k2=k_over_2_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-tau_end=tau_start_inflation-k3=k_over_2-k2=k_over_2_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
y= cl
LABEL =r'$\delta=1$'
colo =0.15
col = (colo, colo, colo)
ax.plot(x,y,label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)




K0 = loadtxt(ROOT+'final-tau_end=tau_start_inflation-k3=k_over_2-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-tau_end=tau_start_inflation-k3=k_over_2-_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
y= cl
LABEL = r'$\delta=0.1$'
colo =0.15
col = (colo, colo, colo)
ax.plot(x,y,label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)



K0 = loadtxt(ROOT+'final-tau_end=tau_start_inflation-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-tau_end=tau_start_inflation-_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
y= cl
LABEL =r'$\delta=0.05$'
colo =0.30
col = (colo, colo, colo)
ax.plot(x,y,label=LABEL,color = col,ls='none',marker='o',markersize=marker_size)



alpha = 0.67
beta=2.
K0 = loadtxt(ROOT+'final-tau_end=tau_start_inflation-_lqc_derived_parameters.dat')
kstar=K0[0]
K0 = loadtxt(ROOT+'final-tau_end=tau_start_inflation-_bispectrum_equi_lqc_s.dat')
ell = K0[:,0]/kstar
cl = K0[:,1]
x= ell
l1=1.
l2=1.
l3=1.
y= beta*np.exp(-alpha*(l1+l2+l3)*ell)


LABEL =r'$\propto\mathrm{exp}(-\alpha k)$'
colo =0.
col = (colo, colo, colo)
ax.plot(x,y,label=LABEL,color = col,ls='-')
ax.plot(x,-y,color = col,ls='-')










plt.text(0.55,0.9,r'$\rho_{_{\mathrm{B}}}=0.41\,m_{_{\mathrm{Pl}}}^4$\quad\quad\quad$\phi_{_\mathrm{B}}=1.15\,m_{_{\mathrm{Pl}}}$',horizontalalignment='center',
     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)




#ax.set_xlim(3.e-6,4e0)
ax.set_ylim(-8.e10,8.e10)
ax.set_xscale('log')
ax.set_yscale('symlog',linthreshy=1.e-5)

ax.set_xlabel(r'$k/k_{\star}$',size=title_size)
ax.set_ylabel(r'$|f_{_\mathrm{NL}}(k)|$',size=title_size)
ax.yaxis.set_label_coords(-.09,0.5) 


ax.legend(loc='lower center',ncol=2,prop={'size':legend_size},handlelength=handle_length,frameon=True)
ax.tick_params(axis = 'x',which='both',length=5,direction='in', pad=10)
ax.tick_params(axis = 'y',which='both',length=5,direction='in', pad=5)

plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)

ax.xaxis.set_ticks_position('both')

ax.yaxis.set_ticks_position('both')





fig.tight_layout()



#plt.setp(plt.axes().get_yticklabels(), rotation='vertical', fontsize=14)
#plt.setp(plt.axes().get_xticklabels(), fontsize=14)
#plt.xlim(2,2000)
#plt.ylim(1.e0,1.e9)
#plt.xlabel('$k/k_{\star}$',size=20)
#plt.ylabel('$P(k)$',size=20)
#plt.legend(loc=4,prop={'size':16})
#plt.axes().set_xscale('log')
#plt.axes().set_yscale('log')

#plt.savefig("fNL_no-redef-@-start-inflation.pdf",format='pdf',bbox_inches='tight')
