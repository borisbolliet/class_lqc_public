# %%
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.interpolate import spline
import numpy as np
from numpy import *
import pylab
import scipy
from matplotlib import rc, rcParams, pyplot
from matplotlib.pyplot import figure, axes, plot, xlabel, ylabel, title, grid, savefig, show
from matplotlib.ticker import MaxNLocator
######################################################################
figure(1,figsize=(8,6))
######################################################################
rc('font', family='TimesRoman', weight = 'extra bold', size = 18.0)
rc('text', usetex=True)
rc('axes', linewidth = 2, labelsize = 'large')  
rc('xtick', labelsize= 'medium')
rcParams['xtick.major.size'] = 12.0 
rcParams['xtick.minor.size'] = 8.0
rcParams['xtick.major.pad'] = 12.0 
rcParams['xtick.minor.pad'] = 12.0
rc('ytick', labelsize= 'medium')  
rcParams['ytick.major.size'] = 12.0 
rcParams['ytick.minor.size'] = 8.0
rcParams['ytick.major.pad'] = 12.0 
rcParams['ytick.minor.pad'] = 12.0
rc('lines', linewidth = 1.5, markeredgewidth=2.0)
rc('savefig', dpi=300)
######################################################################
# Fixing space around the plot
pylab.axes([0.145,0.125,0.825,0.825])

#ax.xaxis.set_major_locator(xmajorLocator)
#ax.xaxis.set_minor_locator(xminorLocator)
#ax.yaxis.set_major_locator(ymajorLocator)
#ax.yaxis.set_minor_locator(yminorLocator)

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_bg = genfromtxt('output/test-phasespace-positive_branch-U1-050617-_background_lqc.dat')
t = data_bg[:,0]
a = data_bg[:,1]
x = data_bg[:,2]
y = data_bg[:,3]
H = data_bg[:,4]
epsilon_H = data_bg[:,5]
epsilon_2 = data_bg[:,6]
rho = data_bg[:,7]
#phi = data_bg[:,9]
phi_dot = data_bg[:,10]
#f_S = data_bg[:,13]
H2_f_S_Q = data_bg[:,11]
pia_phase = data_bg[:,23]
pia_phys = data_bg[:,24]
H2_f_S_Q_phys = data_bg[:,25]
v = data_bg[:,19]
h = data_bg[:,20]
phi = data_bg[:,21]
Pphi = data_bg[:,22]
zppbyz = data_bg[:,17]
appbya = data_bg[:,18]
kp = 1.705662003245e+02

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_bg_rho41 = genfromtxt('output/test-phasespace-positive_branch-U2-050617-_background_lqc.dat')
t_rho41 = data_bg_rho41[:,0]
a_rho41 = data_bg_rho41[:,1]
x_rho41 = data_bg_rho41[:,2]
y_rho41 = data_bg_rho41[:,3]
H_rho41 = data_bg_rho41[:,4]
epsilon_H_rho41 = data_bg_rho41[:,5]
epsilon_2_rho41 = data_bg_rho41[:,6]
rho_rho41 = data_bg_rho41[:,7]
#phi = data_bg[:,9]
phi_dot_rho41 = data_bg[:,10]
#f_S = data_bg[:,13]
H2_f_S_Q_rho41 = data_bg_rho41[:,11]
pia_phase_rho41 = data_bg_rho41[:,23]
pia_phys_rho41 = data_bg_rho41[:,24]
H2_f_S_Q_phys_rho41 = data_bg_rho41[:,25]
v_rho41 = data_bg_rho41[:,19]
h_rho41 = data_bg_rho41[:,20]
phi_rho41 = data_bg_rho41[:,21]
Pphi_rho41 = data_bg_rho41[:,22]
zppbyz_rho41 = data_bg_rho41[:,17]
appbya_rho41 = data_bg_rho41[:,18]
Pphidot_rho41 = data_bg_rho41[:,28]
piadot_rho41 = data_bg_rho41[:,29]
kp_rho41 = 1.705662003245e+02

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_bg_U3 = genfromtxt('output/test-phasespace-positive_branch-U3-060617-_background_lqc.dat')
t_U3 = data_bg_U3[:,0]
a_U3 = data_bg_U3[:,1]
x_U3 = data_bg_U3[:,2]
y_U3 = data_bg_U3[:,3]
H_U3 = data_bg_U3[:,4]
epsilon_H_U3 = data_bg_U3[:,5]
epsilon_2_U3 = data_bg_U3[:,6]
rho_U3 = data_bg_U3[:,7]
#phi = data_bg[:,9]
phi_dot_U3 = data_bg_U3[:,10]
#f_S = data_bg[:,13]
H2_f_S_Q_U3 = data_bg_U3[:,11]
pia_phase_U3 = data_bg_U3[:,23]
pia_phys_U3 = data_bg_U3[:,24]
H2_f_S_Q_phys_U3 = data_bg_U3[:,25]
v_U3 = data_bg_U3[:,19]
h_U3 = data_bg_U3[:,20]
phi_U3 = data_bg_U3[:,21]
Pphi_U3 = data_bg_U3[:,22]
zppbyz_U3 = data_bg_U3[:,17]
appbya_U3 = data_bg_U3[:,18]
Pphidot_U3 = data_bg_U3[:,28]
piadot_U3 = data_bg_U3[:,29]
kp_U3 = 1.705662003245e+02

# %%
data_bg_nb = genfromtxt('output/background_lqc-nb.txt')
t_nb = data_bg_nb[:,0]
Pphidot1_nb=data_bg_nb[:,8]
Pphidot_nb=data_bg_nb[:,9]
pia_nb = data_bg_nb[:,10]
piadot_nb = data_bg_nb[:,11]
phidot_nb = data_bg_nb[:,6]

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
#plot(t_nb, absolute(Pphidot1_nb), color='red', linestyle='-',label=r'nb derived from $\dot p_{\phi}')
plot(t_nb, absolute(phidot_nb), color='green', linestyle='-',label=r'nb')
plot(t_rho41, absolute(phi_dot_rho41), color='blue', linestyle='--',label=r'.c')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
#plt.xscale('symlog')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\dot\phi$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e1,1.e1])
#pylab.ylim([1e-1,1e5])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-10.0, 10.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
#plot(t_nb, absolute(Pphidot1_nb), color='red', linestyle='-',label=r'nb derived from $\dot p_{\phi}')
plot(t_nb, absolute(Pphidot_nb), color='green', linestyle='-',label=r'nb derived from $(a^3\dot\phi)^{^.}$')
plot(t_rho41, absolute(Pphidot_rho41), color='blue', linestyle='--',label=r'.c')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
#plt.xscale('symlog')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\dot p_{\phi}$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e1,1.e1])
pylab.ylim([1e-13,1e-4])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (1e-13, 0.0001)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
#plot(t_nb, absolute(Pphidot1_nb), color='red', linestyle='-',label=r'nb derived from $\dot p_{\phi}')
plot(t_nb, absolute(pia_nb), color='green', linestyle='-',label=r'nb')
plot(t_rho41, absolute(pia_phase_rho41), color='blue', linestyle='--',label=r'.c')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
plt.xscale('symlog')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\pi_a$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e5,1.e7])
pylab.ylim([1e-1,1e5])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (0.1, 100000.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
#plot(t_nb, absolute(Pphidot1_nb), color='red', linestyle='-',label=r'nb derived from $\dot p_{\phi}')
plot(t_nb, absolute(piadot_nb), color='green', linestyle='--',label=r'nb ')
plot(t_rho41, absolute(piadot_rho41), color='blue', linestyle='--',label=r'.c')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
plt.xscale('symlog')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\dot\pi_a$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e5,1.e7])
pylab.ylim([1e-7,1e10])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (1e-07, 10000000000.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, a, color='red', linestyle='-',label=r'$U_1$')
plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'$U_2$')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
#plt.xscale('symlog')
#plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$a$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e1,1.e1])
pylab.ylim([0,7])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (0, 7)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, H, color='red', linestyle='-',label=r'U_1')
plot(t_rho41, H_rho41, color='blue', linestyle='--',label=r'$u_2$')
#plot(t_nb, H_nb, color='blue', linestyle='--',label=r'$new$')
#plt.xscale('symlog')
#plt.yscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$H$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e1,1.e1])
#pylab.ylim([-0.5,2])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-10.0, 10.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, phi, color='red', linestyle='-',label=r'$U_1$')
plot(t_rho41, phi_rho41, color='blue', linestyle='--',label=r'U_2')
#plot(t_nb, phi_nb, color='blue', linestyle='--',label=r'.nb')
plt.xscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\phi$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e7,1.e7])
#pylab.ylim([-0.5,2])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-10000000.0, 10000000.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, phi_dot, color='red', linestyle='-',label=r'$U_1$')
plot(t_rho41, phi_dot_rho41, color='blue', linestyle='--',label=r'$U_2$')
#plot(t_nb, phidot_nb, color='blue', linestyle='--',label=r'.nb')
plt.xscale('symlog')
plt.xscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\dot\phi$')
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.xlim([-1.e7,1.e7])
#pylab.ylim([-0.5,2])
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()
# Out:
# (-10000000.0, 10000000.0)

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, absolute(H2_f_S_Q), color='red', linestyle='-',label=r'$|{\cal U}_1|$')
plot(t_rho41, absolute(H2_f_S_Q_rho41), color='blue', linestyle='--',label=r'${\cal U}_2$')
plot(t_U3, absolute(H2_f_S_Q_U3), color='green', linestyle=':',label=r'$|U_3|$')
plot(t, (kp/a)**2, color='black', linestyle='--',label=r'$k_{\star}^2/a^2$')
plt.xscale('symlog')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$|{\cal U}|$')
pylab.xlim([-1.e7,1.e7])
pylab.ylim([1.e-13,1e7])
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.savefig('UvsU.pdf', bbox_inches='tight')
#pylab.show()

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, absolute(zppbyz), color='red', linestyle='-',label=r'$|U_1|$')
plot(t_rho41, absolute(zppbyz_rho41), color='blue', linestyle='--',label=r'$U2$')
plot(t_U3, absolute(zppbyz_U3), color='green', linestyle=':',label=r'$|U_3|$')
plot(t, (kp/a)**2, color='black', linestyle='--',label=r'$k_{\star}^2/a^2$')
plt.xscale('symlog')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$|f|$')
pylab.xlim([-1.e6,1.e7])
pylab.ylim([1.e-13,1.1e7])
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.savefig('zsppbyzs-UvsU.pdf', bbox_inches='tight')
#pylab.show()

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, absolute(appbya), color='red', linestyle='-',label=r'$|-{\cal U}_1|$')
plot(t_rho41, absolute(appbya_rho41), color='blue', linestyle='--',label=r'$|U_2|$')
plot(t_U3, absolute(appbya_U3), color='green', linestyle=':',label=r'$|-{\cal U}_3|$')
plot(t, (kp/a)**2, color='black', linestyle='--',label=r'$k_{\star}^2/a^2$')
plt.xscale('symlog')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$a^{\prime\prime}/a$')
pylab.xlim([-1.e7,1.e7])
pylab.ylim([1.e-13,1e5])
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t,pia_phase , color='red', linestyle='-',label=r'$pia_{phase}$')
plot(t, pia_phys, color='g', linestyle='--',label=r'$pia_{phys}$')
plot(t, pia_phys-3.14/0.11*a*a*6, color='g', linestyle='--',label=r'$pia_{phys}$')
#plot(t_b, absolute(H2_f_S_Q_b), color='blue', linestyle='--',label=r'$old$')
plt.xscale('symlog')
plt.yscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\pi_a$')
pylab.xlim([-1.e1,1.e1])
pylab.ylim([-1.e5,1e5])
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, absolute(epsilon_H), color='red', linestyle='-',label=r'U_1')
plot(t_rho41, absolute(epsilon_H_rho41), color='b', linestyle='--',label=r'U_2')
#plot(t_b, absolute(H2_f_S_Q_b), color='blue', linestyle='--',label=r'$old$')
plt.xscale('symlog')
#plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\epsilon_H$')
pylab.xlim([-1.e7,1.e7])
#pylab.ylim([1.e-13,1e-7])
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, epsilon_2, color='red', linestyle='-',label=r'U_1')
plot(t_rho41, epsilon_2_rho41, color='b', linestyle='--',label=r'U_2')
#plot(t_b, absolute(H2_f_S_Q_b), color='blue', linestyle='--',label=r'$old$')
plt.xscale('symlog')
#plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\epsilon_2$')
pylab.xlim([-1.e7,1.e7])
pylab.ylim([-0.5,4])
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
#pylab.savefig('fnl-lqc-sl-slowroll-x_ini_3p19em5.pdf', bbox_inches='tight')
#pylab.show()

# %%
data_sps = genfromtxt("output/test-phasespace-positive_branch-U1-050617-_pk_lqc_s.dat")
k = data_sps[:,0]
Ps = data_sps[:,1]

# %%
data_sps_rho41 = genfromtxt("output/test-phasespace-positive_branch-U2-050617-_pk_lqc_s.dat")
k_rho41 = data_sps_rho41[:,0]
Ps_rho41 = data_sps_rho41[:,1]

# %%
data_sps_U3 = genfromtxt("output/test-phasespace-positive_branch-U3-060617-_pk_lqc_s.dat")
k_U3 = data_sps_U3[:,0]
Ps_U3 = data_sps_U3[:,1]

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(k_rho41/kp_rho41, Ps_rho41, color='b', linestyle='-',label=r'$U_2$')
plot(k/kp, Ps, color='red', linestyle='--',label=r'$U_1$')
plot(k_U3/kp, Ps_U3, color='green', linestyle=':',label=r'$U_3$')
#plot(t_b, absolute(H2_f_S_Q_b), color='blue', linestyle='--',label=r'$old$')
plt.xscale('log')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$k/k_{\star}$')
pylab.ylabel(r'${\cal P}_s(k)$')
#pylab.xlim([-1.e7,1.e7])
pylab.ylim([1.e-10,1e-6])
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.savefig('sps-UvsU.pdf', bbox_inches='tight')
#pylab.show()

# %%
data_sbs = genfromtxt("output/test-phasespace-positive_branch-U1-050617-_bispectrum_equi_lqc_s.dat")
k = data_sbs[:,0]
fnl = data_sbs[:,1]

# %%
data_sbs_rho41 = genfromtxt("output/test-phasespace-positive_branch-U2-050617-_bispectrum_equi_lqc_s.dat")
k_rho41 = data_sbs_rho41[:,0]
fnl_rho41 = data_sbs_rho41[:,1]

# %%
data_sbs_U3 = genfromtxt("output/test-phasespace-positive_branch-U3-060617-_bispectrum_equi_lqc_s.dat")
k_U3 = data_sbs_U3[:,0]
fnl_U3 = data_sbs_U3[:,1]

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(k/kp, absolute(fnl), color='red', linestyle='-',label=r'$U_1$')
plot(k_rho41/kp_rho41, absolute(fnl_rho41), color='b', linestyle='-',label=r'$U_2$')
plot(k_U3/kp, absolute(fnl_U3), color='green', linestyle='-',label=r'$U_3$')
#plot(k_phys/kp, absolute(fnl_phys), color='g', linestyle='--',label=r'$fnl_{phys}$')
#plot(k_rho41/kp_rho41, absolute(fnl_rho41), color='b', linestyle='--',label=r'$fnl_{\rho_0.41}}$')
#plot(t_b, absolute(H2_f_S_Q_b), color='blue', linestyle='--',label=r'$old$')
plt.xscale('log')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$k/k_{\star}$')
pylab.ylabel(r'$f_{_{\rm NL}}(k)$')
#pylab.xlim([-1.e7,1.e7])
#pylab.ylim([1.e-2,1e-1])
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
pylab.savefig('fnl-UvsU.pdf', bbox_inches='tight')
#pylab.show()

# %%
data_tps_rho41 = genfromtxt("output/test-phasespace-positive_branch-U2-060617-_pk_lqc_t.dat")
k_rho41 = data_tps_rho41[:,0]
Pt_rho41 = data_tps_rho41[:,1]

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
#plot(k/kp, absolute(fnl), color='red', linestyle='-',label=r'$U_1$')
plot(k_rho41/kp_rho41, absolute(Pt_rho41), color='b', linestyle='-',label=r'$U_2$')
#plot(k_phys/kp, absolute(fnl_phys), color='g', linestyle='--',label=r'$fnl_{phys}$')
#plot(k_rho41/kp_rho41, absolute(fnl_rho41), color='b', linestyle='--',label=r'$fnl_{\rho_0.41}}$')
#plot(t_b, absolute(H2_f_S_Q_b), color='blue', linestyle='--',label=r'$old$')
plt.xscale('log')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$k/k_{\star}$')
pylab.ylabel(r'${\cal P}_t(k)$')
#pylab.xlim([1.e0,1.e1])
#pylab.ylim([1.e-2,1e-1])
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
#pylab.savefig('fnl-UvsU.pdf', bbox_inches='tight')
#pylab.show()

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
#plot(k/kp, absolute(fnl), color='red', linestyle='-',label=r'$U_1$')
plot(k_rho41/kp_rho41, absolute(Pt_rho41/Ps_rho41), color='b', linestyle='-',label=r'$U_2$')
#plot(k_phys/kp, absolute(fnl_phys), color='g', linestyle='--',label=r'$fnl_{phys}$')
#plot(k_rho41/kp_rho41, absolute(fnl_rho41), color='b', linestyle='--',label=r'$fnl_{\rho_0.41}}$')
#plot(t_b, absolute(H2_f_S_Q_b), color='blue', linestyle='--',label=r'$old$')
plt.xscale('log')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$k/k_{\star}$')
pylab.ylabel(r'$r$')
#pylab.xlim([1.e0,1.e1])
#pylab.ylim([1.e-1,2e-1])
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
#pylab.savefig('fnl-UvsU.pdf', bbox_inches='tight')
#pylab.show()

# %%
data_tbs_rho41 = genfromtxt("output/test-phasespace-positive_branch-U2-060617-_bispectrum_equi_lqc_t.dat")
k_rho41 = data_tbs_rho41[:,0]
hnl_rho41 = data_tbs_rho41[:,1]

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
#plot(k/kp, absolute(fnl), color='red', linestyle='-',label=r'$U_1$')
plot(k_rho41/kp_rho41, absolute(hnl_rho41), color='b', linestyle='-',label=r'$U_2$')
#plot(k_phys/kp, absolute(fnl_phys), color='g', linestyle='--',label=r'$fnl_{phys}$')
#plot(k_rho41/kp_rho41, absolute(fnl_rho41), color='b', linestyle='--',label=r'$fnl_{\rho_0.41}}$')
#plot(t_b, absolute(H2_f_S_Q_b), color='blue', linestyle='--',label=r'$old$')
plt.xscale('log')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$k/k_{\star}$')
pylab.ylabel(r'$h_{_{\rm NL}}(k)$')
#pylab.xlim([1.e0,1.e1])
#pylab.ylim([1.e-1,1e1])
legend=pylab.legend(loc='best', shadow=False,frameon=False,prop={'size':13})
#pylab.savefig('fnl-UvsU.pdf', bbox_inches='tight')
#pylab.show()
