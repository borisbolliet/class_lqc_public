# %%
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.interpolate import spline
import numpy as np
from numpy import *
import pylab
import scipy
from matplotlib import rc, rcParams, pyplot
from matplotlib.pyplot import figure, axes, plot, xlabel, ylabel, title, grid, savefig, show
from matplotlib.ticker import MaxNLocator
######################################################################
figure(1,figsize=(8,6))
######################################################################
rc('font', family='TimesRoman', weight = 'extra bold', size = 18.0)
rc('text', usetex=True)
rc('axes', linewidth = 1, labelsize = 'large')  
rc('xtick', labelsize= 'medium')
rcParams['xtick.major.size'] = 6. 
rcParams['xtick.minor.size'] = 3
rcParams['xtick.major.pad'] = 12 
rcParams['xtick.minor.pad'] = 8
rc('ytick', labelsize= 'medium')  
rcParams['ytick.major.size'] = 6 
rcParams['ytick.minor.size'] = 3
rcParams['ytick.major.pad'] = 12 
rcParams['ytick.minor.pad'] = 8
rc('lines', linewidth = 1.5, markeredgewidth=2.0)
rc('savefig', dpi=300)
######################################################################
# Fixing space around the plot
pylab.axes([0.145,0.125,0.825,0.825])

#ax.xaxis.set_major_locator(xmajorLocator)
#ax.xaxis.set_minor_locator(xminorLocator)
#ax.yaxis.set_major_locator(ymajorLocator)
#ax.yaxis.set_minor_locator(yminorLocator)

# %%
#Reading data from files and plotting them
#read from textfile to x and y
#\delta = 10, tol = 1.e-8
data_sps = genfromtxt('job30344/output/test-_pk_lqc_s.dat')
kp1 = 1.788155105133e+03
k_1 = data_sps[:,0]
Ps_1 = data_sps[:,1]

# %%
#Reading data from files and plotting them
#read from textfile to x and y
#\delta = 10, tol = 1.e-12
data_sps = genfromtxt('job30343/output/test-_pk_lqc_s.dat')
kp2 = 1.788155105133e+03
k_2 = data_sps[:,0]
Ps_2 = data_sps[:,1]

# %%
#Reading data from files and plotting them
#read from textfile to x and y
#\delta = 10, tol = 1.e-16
data_sps = genfromtxt('job30342/output/test-_pk_lqc_s.dat')
kp3 = 1.788155105133e+03
k_3 = data_sps[:,0]
Ps_3 = data_sps[:,1]

# %%
#Reading data from files and plotting them
#read from textfile to x and y
#\delta = 20, tol = 1.e-8
data_sps = genfromtxt('job30346/output/test-_pk_lqc_s.dat')
kp4 = 1.788155105133e+03
k_4 = data_sps[:,0]
Ps_4 = data_sps[:,1]

# %%
#Reading data from files and plotting them
#read from textfile to x and y
#\delta = 20, tol = 1.e-12
data_sps = genfromtxt('job30347/output/test-_pk_lqc_s.dat')
kp5 = 1.788155105133e+03
k_5 = data_sps[:,0]
Ps_5 = data_sps[:,1]

# %%
#Reading data from files and plotting them
#read from textfile to x and y
#\delta = 20, tol = 1.e-16
data_sps = genfromtxt('job30348/output/test-_pk_lqc_s.dat')
kp6 = 1.788155105133e+03
k_6 = data_sps[:,0]
Ps_6 = data_sps[:,1]

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(k_1/kp1, Ps_1, color='red', linestyle='None',marker='o',markeredgewidth=0.,markersize = 6,label=r'tol $= 10^{-8}$')
plot(k_2/kp2, Ps_2, color='green', linestyle='None',marker='v',markeredgewidth=0.,markersize = 5,label=r'tol $= 10^{-12}$')
plot(k_3/kp3, Ps_3, color='blue', linestyle='None',marker='*',markeredgewidth=0.,markersize = 4,label=r'tol $= 10^{-16}$')
#plot(k_p1/kp, Ps_p1, color='grey', linestyle='None',marker='o',markeredgewidth=0.,markersize = 4)
#plot(k_o/kp, Ps_o, color='red', linestyle='-',linewidth=0.25)
#plot([1.607738e+01/kp,1.607738e+01/kp],[1e-12,1e-6],linestyle='--',color='black',linewidth=0.5)
#pylab.annotate(r'$k_{_{\rm LQC}}$', xy=(275,290),  xycoords='figure points',fontsize=12)
plt.xscale('log')
plt.yscale('log')
legend=pylab.legend(loc='best', numpoints=1, shadow=False,frameon=True,prop={'size':13})
pylab.xlabel(r'$k/k_*$')
pylab.ylabel(r'${\cal P}_s(k)$')
pylab.xlim([7.e-4,1.e1])
pylab.ylim([1e-12,1e-7])
pylab.savefig('Ps-accuracy-delta_10.pdf', bbox_inches='tight')
#pylab.show()

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(k_4/kp4, Ps_4, color='red', linestyle='None',marker='o',markeredgewidth=0.,markersize = 6,label=r'tol $= 10^{-8}$')
plot(k_5/kp5, Ps_5, color='green', linestyle='None',marker='v',markeredgewidth=0.,markersize = 5,label=r'tol $= 10^{-12}$')
plot(k_6/kp6, Ps_6, color='blue', linestyle='None',marker='*',markeredgewidth=0.,markersize = 4,label=r'tol $= 10^{-16}$')
#plot(k_p1/kp, Ps_p1, color='grey', linestyle='None',marker='o',markeredgewidth=0.,markersize = 4)
#plot(k_o/kp, Ps_o, color='red', linestyle='-',linewidth=0.25)
#plot([1.607738e+01/kp,1.607738e+01/kp],[1e-12,1e-6],linestyle='--',color='black',linewidth=0.5)
#pylab.annotate(r'$k_{_{\rm LQC}}$', xy=(275,290),  xycoords='figure points',fontsize=12)
plt.xscale('log')
plt.yscale('log')
legend=pylab.legend(loc='best', numpoints=1, shadow=False,frameon=True,prop={'size':13})
pylab.xlabel(r'$k/k_*$')
pylab.ylabel(r'${\cal P}_s(k)$')
pylab.xlim([7.e-4,1.e1])
pylab.ylim([1e-12,1e-7])
pylab.savefig('Ps-accuracy-delta_20.pdf', bbox_inches='tight')
#pylab.show()

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(k_1/kp1, Ps_1, color='red', linestyle='None',marker='o',markeredgewidth=0.,markersize = 6,label=r'tol $= 10^{-8}, \delta = 0.1$')
plot(k_2/kp2, Ps_2, color='green', linestyle='None',marker='v',markeredgewidth=0.,markersize = 5,label=r'tol $= 10^{-12}, \delta = 0.1$')
plot(k_3/kp3, Ps_3, color='blue', linestyle='None',marker='*',markeredgewidth=0.,markersize = 6,label=r'tol $= 10^{-16}, \delta = 0.1$')
plot(k_4/kp4, Ps_4, color='orange', linestyle='None',marker='^',markeredgewidth=0.,markersize = 6,label=r'tol $= 10^{-8}, \delta = 0.05$')
plot(k_5/kp5, Ps_5, color='yellow', linestyle='None',marker='+',markeredgewidth=1.,markersize = 5,label=r'tol $= 10^{-12}, \delta = 0.05$')
plot(k_6/kp6, Ps_6, color='magenta', linestyle='None',marker='.',markeredgewidth=0.,markersize = 4,label=r'tol $= 10^{-16}, \delta = 0.05$')
#plot(k_p1/kp, Ps_p1, color='grey', linestyle='None',marker='o',markeredgewidth=0.,markersize = 4)
#plot(k_o/kp, Ps_o, color='red', linestyle='-',linewidth=0.25)
#plot([1.607738e+01/kp,1.607738e+01/kp],[1e-12,1e-6],linestyle='--',color='black',linewidth=0.5)
#pylab.annotate(r'$k_{_{\rm LQC}}$', xy=(275,290),  xycoords='figure points',fontsize=12)
plt.xscale('log')
plt.yscale('log')
legend=pylab.legend(loc='best', numpoints=1, shadow=False,frameon=True,prop={'size':13})
pylab.xlabel(r'$k/k_*$')
pylab.ylabel(r'${\cal P}_s(k)$')
pylab.xlim([7.e-4,1.e1])
pylab.ylim([1e-12,1e-7])
pylab.savefig('Ps-accuracy-delta_10_20.pdf', bbox_inches='tight')
#pylab.show()

# %%
#Reading data from files and plotting them
#read from textfile to x and y
#\delta = 10, tol = 1.e-8
data_sps = genfromtxt('job30344/output/test-_bispectrum_equi_lqc_s.dat')
kp1 = 1.788155105133e+03
k_1 = data_sps[:,0]
fnl_1 = data_sps[:,1]
#
data_sps = genfromtxt('job30343/output/test-_bispectrum_equi_lqc_s.dat')
kp2 = 1.788155105133e+03
k_2 = data_sps[:,0]
fnl_2 = data_sps[:,1]
#
data_sps = genfromtxt('job30342/output/test-_bispectrum_equi_lqc_s.dat')
kp3 = 1.788155105133e+03
k_3 = data_sps[:,0]
fnl_3 = data_sps[:,1]
#
data_sps = genfromtxt('job30346/output/test-_bispectrum_equi_lqc_s.dat')
kp4 = 1.788155105133e+03
k_4 = data_sps[:,0]
fnl_4 = data_sps[:,1]
#
data_sps = genfromtxt('job30347/output/test-_bispectrum_equi_lqc_s.dat')
kp5 = 1.788155105133e+03
k_5 = data_sps[:,0]
fnl_5 = data_sps[:,1]
#
data_sps = genfromtxt('job30348/output/test-_bispectrum_equi_lqc_s.dat')
kp6 = 1.788155105133e+03
k_6 = data_sps[:,0]
fnl_6 = data_sps[:,1]

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(k_1/kp1, abs(fnl_1), color='red', linestyle='None',marker='o',markeredgewidth=0.,markersize = 6,label=r'tol $= 10^{-8}$')
plot(k_2/kp2, abs(fnl_2), color='green', linestyle='None',marker='v',markeredgewidth=0.,markersize = 6,label=r'tol $= 10^{-12}$')
plot(k_3/kp3, abs(fnl_3), color='blue', linestyle='None',marker='+',markeredgewidth=1.,markersize = 6,label=r'tol $= 10^{-16}$')

#pylab.annotate(r'$\rho_b = 0.41 m_{_{\rm Pl}}^4$', xy=(2.e0,1.e5),  xycoords='data',fontsize=12)
#pylab.annotate(r'$k_1 = k_2 = k_3 = k$', xy=(2.e0,3.e4),  xycoords='data',fontsize=12)
#plot(k_p1/kp, Ps_p1, color='grey', linestyle='None',marker='o',markeredgewidth=0.,markersize = 4)
#plot(k_o/kp, Ps_o, color='red', linestyle='-',linewidth=0.25)
#plot([1.607738e+01/kp,1.607738e+01/kp],[1e-12,1e-6],linestyle='--',color='black',linewidth=0.5)
#pylab.annotate(r'$k_{_{\rm LQC}}$', xy=(275,290),  xycoords='figure points',fontsize=12)
plt.xscale('log')
plt.yscale('log')
legend=pylab.legend(loc='best', numpoints=1, shadow=False,frameon=True,prop={'size':13})
pylab.xlabel(r'$k/k_*$')
pylab.ylabel(r'$f_{_{\rm NL}}(k)$')
pylab.xlim([7.e-4,1.e1])
pylab.ylim([1e-3,1e6])
pylab.savefig('fnl-el-accuracy-delta_10.pdf', bbox_inches='tight')
#pylab.show()

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(k_4/kp4, abs(fnl_4), color='red', linestyle='None',marker='o',markeredgewidth=0.,markersize = 6,label=r'tol $= 10^{-8}$')
plot(k_5/kp5, abs(fnl_5), color='green', linestyle='None',marker='v',markeredgewidth=0.,markersize = 6,label=r'tol $= 10^{-12}$')
plot(k_6/kp6, abs(fnl_6), color='blue', linestyle='None',marker='+',markeredgewidth=1.,markersize = 6,label=r'tol $= 10^{-16}$')

#pylab.annotate(r'$\rho_b = 0.41 m_{_{\rm Pl}}^4$', xy=(2.e0,1.e5),  xycoords='data',fontsize=12)
#pylab.annotate(r'$k_1 = k_2 = k_3 = k$', xy=(2.e0,3.e4),  xycoords='data',fontsize=12)
#plot(k_p1/kp, Ps_p1, color='grey', linestyle='None',marker='o',markeredgewidth=0.,markersize = 4)
#plot(k_o/kp, Ps_o, color='red', linestyle='-',linewidth=0.25)
#plot([1.607738e+01/kp,1.607738e+01/kp],[1e-12,1e-6],linestyle='--',color='black',linewidth=0.5)
#pylab.annotate(r'$k_{_{\rm LQC}}$', xy=(275,290),  xycoords='figure points',fontsize=12)
plt.xscale('log')
plt.yscale('log')
legend=pylab.legend(loc='best', numpoints=1, shadow=False,frameon=True,prop={'size':13})
pylab.xlabel(r'$k/k_*$')
pylab.ylabel(r'$f_{_{\rm NL}}(k)$')
pylab.xlim([7.e-4,1.e1])
pylab.ylim([1e-3,1e6])
pylab.savefig('fnl-el-accuracy-delta_20.pdf', bbox_inches='tight')
#pylab.show()

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(k_1/kp1, abs(fnl_1), color='red', linestyle='None',marker='o',markeredgewidth=0.,markersize = 6,label=r'tol $= 10^{-8}, \delta = 0.1$')
plot(k_2/kp2, abs(fnl_2), color='green', linestyle='None',marker='v',markeredgewidth=0.,markersize = 6,label=r'tol $= 10^{-8}, \delta = 0.1$')
plot(k_3/kp3, abs(fnl_3), color='blue', linestyle='None',marker='+',markeredgewidth=1.,markersize = 6,label=r'tol $= 10^{-8}, \delta = 0.1$')
plot(k_4/kp4, abs(fnl_4), color='orange', linestyle='None',marker='s',markeredgewidth=0.,markersize = 4,label=r'tol $= 10^{-8}, \delta = 0.05$')
plot(k_5/kp5, abs(fnl_5), color='yellow', linestyle='None',marker='^',markeredgewidth=0.,markersize = 4,label=r'tol $= 10^{-8}, \delta = 0.05$')
plot(k_6/kp6, abs(fnl_6), color='magenta', linestyle='None',marker='.',markeredgewidth=1.,markersize = 4,label=r'tol $= 10^{-8}, \delta = 0.05$')

#pylab.annotate(r'$\rho_b = 0.41 m_{_{\rm Pl}}^4$', xy=(2.e0,1.e5),  xycoords='data',fontsize=12)
#pylab.annotate(r'$k_1 = k_2 = k_3 = k$', xy=(2.e0,3.e4),  xycoords='data',fontsize=12)
#plot(k_p1/kp, Ps_p1, color='grey', linestyle='None',marker='o',markeredgewidth=0.,markersize = 4)
#plot(k_o/kp, Ps_o, color='red', linestyle='-',linewidth=0.25)
#plot([1.607738e+01/kp,1.607738e+01/kp],[1e-12,1e-6],linestyle='--',color='black',linewidth=0.5)
#pylab.annotate(r'$k_{_{\rm LQC}}$', xy=(275,290),  xycoords='figure points',fontsize=12)
plt.xscale('log')
plt.yscale('log')
legend=pylab.legend(loc='best', numpoints=1, shadow=False,frameon=True,prop={'size':13})
pylab.xlabel(r'$k/k_*$')
pylab.ylabel(r'$f_{_{\rm NL}}(k)$')
pylab.xlim([7.e-4,1.e1])
pylab.ylim([1e-4,1e6])
pylab.savefig('fnl-el-accuracy-delta_10_20.pdf', bbox_inches='tight')
#pylab.show()
