# %%
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.interpolate import spline
import numpy as np
from numpy import *
import pylab
import scipy
from matplotlib import rc, rcParams, pyplot
from matplotlib.pyplot import figure, axes, plot, xlabel, ylabel, title, grid, savefig, show
from matplotlib.ticker import MaxNLocator
######################################################################
figure(1,figsize=(8,6))
######################################################################
rc('font', family='TimesRoman', weight = 'extra bold', size = 18.0)
rc('text', usetex=True)
rc('axes', linewidth = 2, labelsize = 'large')  
rc('xtick', labelsize= 'medium')
rcParams['xtick.major.size'] = 12.0 
rcParams['xtick.minor.size'] = 8.0
rcParams['xtick.major.pad'] = 12.0 
rcParams['xtick.minor.pad'] = 12.0
rc('ytick', labelsize= 'medium')  
rcParams['ytick.major.size'] = 12.0 
rcParams['ytick.minor.size'] = 8.0
rcParams['ytick.major.pad'] = 12.0 
rcParams['ytick.minor.pad'] = 12.0
rc('lines', linewidth = 1.5, markeredgewidth=2.0)
rc('savefig', dpi=300)
######################################################################
# Fixing space around the plot
pylab.axes([0.145,0.125,0.825,0.825])

#ax.xaxis.set_major_locator(xmajorLocator)
#ax.xaxis.set_minor_locator(xminorLocator)
#ax.yaxis.set_major_locator(ymajorLocator)
#ax.yaxis.set_minor_locator(yminorLocator)

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_U2 = genfromtxt('output/test-_background_lqc.dat')
t_U2 = data_U2[:,0]
v_U2 = data_U2[:,19]
h_U2 = data_U2[:,20]
phi_U2 = data_U2[:,21]
#Pphi_U2 = data_U2[:,22]
phi_pert_U2 = data_U2[:,9]
Pphi_pert_U2 = data_U2[:,22]
a_U2 = data_U2[:,1]
H_U2 = data_U2[:,4]
U2 = data_U2[:,11]
zsppbyzs_U2 = data_U2[:,17]
appbya_U2 = data_U2[:,18]
pia_U2 = data_U2[:,23]
piadot_U2 = data_U2[:,29]
Pphidot_U2 = data_U2[:,28]
phidot_U2 = data_U2[:,10]

# %%
#Reading data from files and plotting them
#read from textfile to x and y
data_nb = genfromtxt('output/background_lqc-nb.txt')
t_nb = data_nb[:,0]
phi_nb = data_nb[:,1]
Pphi_nb = data_U2[:,2]
v_nb = data_nb[:,3]
h_nb = data_nb[:,4]
a_nb = data_nb[:,5]
H_nb = data_nb[:,6]
phi_pert_nb = data_nb[:,7]
Pphi_pert_nb = data_nb[:,8]
pia_nb = data_nb[:,9]
phidot_nb = data_nb[:,10]
piadot_nb = data_nb[:,12]
Pphidot_nb = data_nb[:,11]
U1_nb = data_nb[:,13]
U2_nb = data_nb[:,14]
U3_nb = data_nb[:,15]
zppoz_nb = data_nb[:,16]
appoa_nb = data_nb[:,17]
pia2a_nb = data_nb[:,18]
pia2adot_nb = data_nb[:,19]
U2pia2_nb = data_nb[:,20]
zsppbyzspia2pm_nb = data_nb[:,21]

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t_U2, pia_U2, color='red', linestyle='-',label=r'.c')
plot(t_nb, pia2a_nb, color='blue', linestyle='--',label=r'.nb')
#plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
plt.xscale('symlog')
plt.yscale('symlog')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\pi_{a_2}$')
pylab.xlim([-1.e5,5.e6])
pylab.ylim([-1.e10,1e4])
legend=pylab.legend(loc='upper left', shadow=False,frameon=False,prop={'size':13})
#
#a = plt.axes([.4, .2, .25, .25])
#plot(t_U2, abs(), color='red', linestyle='-')
#plot(t_nb, abs(zppoz_nb), color='blue', linestyle='--')
#plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
#plt.xscale('symlog')
#plt.yscale('log')
#pylab.xlim([-0.5e0,0.5e0])
#pylab.ylim([1.e-2,1e3])
#plt.yticks(np.linspace(1.e-2,1.e3,5,endpoint=True))
pylab.savefig('pia.pdf', bbox_inches='tight')
#pylab.show()

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t_U2,piadot_U2, color='red', linestyle='-',label=r'.c')
plot(t_nb, pia2adot_nb, color='blue', linestyle='--',label=r'.nb')
#plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
plt.xscale('symlog')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$\dot\pi_{a_2}$')
pylab.xlim([-1.e0,1.e0])
pylab.ylim([1.e-12,1e4])
legend=pylab.legend(loc='upper left', shadow=False,frameon=False,prop={'size':13})
#
#a = plt.axes([.4, .2, .25, .25])
#plot(t_U2, abs(), color='red', linestyle='-')
#plot(t_nb, abs(zppoz_nb), color='blue', linestyle='--')
#plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
#plt.xscale('symlog')
#plt.yscale('log')
#pylab.xlim([-0.5e0,0.5e0])
#pylab.ylim([1.e-2,1e3])
#plt.yticks(np.linspace(1.e-2,1.e3,5,endpoint=True))
pylab.savefig('piadot.pdf', bbox_inches='tight')
#pylab.show()

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t_U2, abs(U2), color='red', linestyle='-' ,label=r'.c')
plot(t_nb, abs(U2pia2_nb),  color = 'blue',linestyle = '--',label=r'.nb')
#plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
plt.xscale('symlog')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'${\cal U}_2$')
pylab.xlim([-1.e2,1.e2])
pylab.ylim([1.e-11,1e-7])
legend=pylab.legend(loc='upper left', shadow=False,frameon=False,prop={'size':13})
#
#a = plt.axes([.4, .2, .25, .25])
#plot(t_U2, abs(), color='red', linestyle='-')
#plot(t_nb, abs(zppoz_nb), color='blue', linestyle='--')
#plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
#plt.xscale('symlog')
#plt.yscale('log')
#pylab.xlim([-0.5e0,0.5e0])
#pylab.ylim([1.e-2,1e3])
#plt.yticks(np.linspace(1.e-2,1.e3,5,endpoint=True))
pylab.savefig('U2.pdf', bbox_inches='tight')
#pylab.show()

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t_U2, abs(zsppbyzs_U2), color='red', linestyle='-',label=r'.c')
plot(t_nb, abs(zsppbyzspia2pm_nb), color='blue', linestyle='--',label=r'.nb')
#plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
plt.xscale('symlog')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$t$')
pylab.ylabel(r'$|f|$')
pylab.xlim([-1.e5,5.e6])
pylab.ylim([1.e-11,1e3])
legend=pylab.legend(loc='upper left', shadow=False,frameon=False,prop={'size':13})
#
#a = plt.axes([.4, .2, .25, .25])
#plot(t_U2, abs(zsppbyzs_U2), color='red', linestyle='-')
#plot(t_nb, abs(zppoz_nb), color='blue', linestyle='--')
#plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
#plt.xscale('symlog')
#plt.yscale('log')
#pylab.xlim([-0.5e0,0.5e0])
#pylab.ylim([1.e-2,1e3])
#plt.yticks(np.linspace(1.e-2,1.e3,5,endpoint=True))
pylab.savefig('f.pdf', bbox_inches='tight')
#pylab.show()

# %%
data_sps = genfromtxt('output/test-_pk_lqc_s.dat')
k = data_sps[:,0]
Ps = data_sps[:,1]
kp = 3.84

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(k/kp, Ps, color='red', linestyle='-',label=r'.c')
#plot(t_nb, abs(zsppbyzspia2pm_nb), color='blue', linestyle='--',label=r'.nb')
#plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
plt.xscale('log')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$k/k_*$')
pylab.ylabel(r'${\cal P}_s$')
#pylab.xlim([-1.e5,5.e6])
#pylab.ylim([1.e-11,1e3])
legend=pylab.legend(loc='upper left', shadow=False,frameon=False,prop={'size':13})
#
#a = plt.axes([.4, .2, .25, .25])
#plot(t_U2, abs(zsppbyzs_U2), color='red', linestyle='-')
#plot(t_nb, abs(zppoz_nb), color='blue', linestyle='--')
#plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
#plt.xscale('symlog')
#plt.yscale('log')
#pylab.xlim([-0.5e0,0.5e0])
#pylab.ylim([1.e-2,1e3])
#plt.yticks(np.linspace(1.e-2,1.e3,5,endpoint=True))
pylab.savefig('Ps-ti_1e-5.pdf', bbox_inches='tight')
#pylab.show()

# %%
data_sbs = genfromtxt('output/test-_bispectrum_equi_lqc_s.dat')
k = data_sbs[:,0]
fnl = data_sbs[:,1]
kp = 3.84

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(k/kp, abs(fnl), color='red', linestyle='-',label=r'.c')
#plot(t_nb, abs(zsppbyzspia2pm_nb), color='blue', linestyle='--',label=r'.nb')
#plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
plt.xscale('log')
plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$k/k_*$')
pylab.ylabel(r'$f_{_{\rm NL}}$')
#pylab.xlim([-1.e5,5.e6])
#pylab.ylim([1.e-11,1e3])
legend=pylab.legend(loc='upper left', shadow=False,frameon=False,prop={'size':13})
#
#a = plt.axes([.4, .2, .25, .25])
#plot(t_U2, abs(zsppbyzs_U2), color='red', linestyle='-')
#plot(t_nb, abs(zppoz_nb), color='blue', linestyle='--')
#plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
#plt.xscale('symlog')
#plt.yscale('log')
#pylab.xlim([-0.5e0,0.5e0])
#pylab.ylim([1.e-2,1e3])
#plt.yticks(np.linspace(1.e-2,1.e3,5,endpoint=True))
pylab.savefig('fnl-ti_1e-5.pdf', bbox_inches='tight')
#pylab.show()

# %%
data_md = genfromtxt('output/test1-perturbations_lqc_k0_s.dat')
t = data_md[:,0]
md_re = data_md[:,2]
md_im = data_md[:,3]

# %%
data_md_nb = genfromtxt('output/modekp.txt')
t_nb = data_md_nb[:,0]
md_re_nb = data_md_nb[:,1]
md_im_nb = data_md_nb[:,2]

# %%
#plot(t, a, color='red', linestyle='solid',label=r'$a$')
#plot(t, H, color='red', linestyle='--',label=r'$H$')
#plot(t, rho, color='blue', linestyle='solid',label=r'$\rho$')
plot(t, md_re, color='red', linestyle='-',label=r'.c')
plot(t_nb, md_re_nb, color='blue', linestyle='--',label=r'.nb')
#plot(t_nb, abs(zsppbyzspia2pm_nb), color='blue', linestyle='--',label=r'.nb')
#plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
plt.xscale('symlog')
#plt.yscale('log')
#plot(t, phi_dot, color='blue', linestyle='-.',label=r'$\dot\phi$')
pylab.xlabel(r'$k/k_*$')
pylab.ylabel(r'${\cal P}_s$')
pylab.xlim([-1.e3,1.e3])
pylab.ylim([-4.e-1,4e-1])
legend=pylab.legend(loc='upper left', shadow=False,frameon=False,prop={'size':13})
#
#a = plt.axes([.4, .2, .25, .25])
#plot(t_U2, abs(zsppbyzs_U2), color='red', linestyle='-')
#plot(t_nb, abs(zppoz_nb), color='blue', linestyle='--')
#plot(t_rho41, a_rho41, color='blue', linestyle='--',label=r'\rho_{0.41}')
#plot(t_nb, a_nb, color='blue', linestyle='--',label=r'.nb')
#plt.xscale('symlog')
#plt.yscale('log')
#pylab.xlim([-0.5e0,0.5e0])
#pylab.ylim([1.e-2,1e3])
#plt.yticks(np.linspace(1.e-2,1.e3,5,endpoint=True))
pylab.savefig('modekp.pdf', bbox_inches='tight')
#pylab.show()
